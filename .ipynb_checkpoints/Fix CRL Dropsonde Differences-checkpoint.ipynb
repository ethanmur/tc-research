# %%
# import packages and plotting scripts

import numpy as np
import os
import matplotlib.pyplot as plt
import xarray as xr
import datetime 
import warnings

os.chdir(  "/Users/etmu9498/Desktop/research/scripts")
import make_plots

# %%
# view datasets

# paths to data
sonde_path_0926 = "/Users/etmu9498/Desktop/research/dropsondes/20210926H1_NETCDF"
sonde_path_0927 = "/Users/etmu9498/Desktop/research/dropsondes/20210927H1_NETCDF"
sonde_path_0929 = "/Users/etmu9498/Desktop/research/dropsondes/20210929H2_NETCDF"
sonde_path_0930 = "/Users/etmu9498/Desktop/research/dropsondes/20210930H1_NETCDF"
crl_path = "/Users/etmu9498/Desktop/research/CRL_data/2021"
tdr_path = "/Users/etmu9498/Desktop/research/sam-tdr/nc-files"

# load data to these variables
tdr_list = make_plots.load_tdr(tdr_path)
crl_list = make_plots.load_crl(crl_path)
sondes_0926 = make_plots.load_sondes(sonde_path_0926)
sondes_0927 = make_plots.load_sondes(sonde_path_0927)
sondes_0929 = make_plots.load_sondes(sonde_path_0929)
sondes_0930 = make_plots.load_sondes(sonde_path_0930)
# Out:
# tdr data files:
# 0) 210926H1_2237_vert_inbound.nc
# 1) 210926H1_2237_vert_outbound.nc
# 2) 210927H1_2205_vert_inbound.nc
# 3) 210927H1_2205_vert_outbound.nc
# 4) 210929H2_2137_vert_inbound.nc
# 5) 210929H2_2137_vert_outbound.nc
#
# crl data files:
# 0) P3_20210811H1_200000-224759.cdf
# 1) P3_20210812H1_095513-125927.cdf
# 2) P3_20210812H2_212248-235510.cdf
# 3) P3_20210813H1_091801-113558.cdf
# 4) P3_20210816H1_085245-123459.cdf
# 5) P3_20210816H1_090000-102359.cdf
# 6) P3_20210817H1_094204-132058.cdf
# 7) P3_20210818H1_211425-244159.cdf
# 8) P3_20210819H1_213003-244159.cdf
# 9) P3_20210820H1_212402-245958.cdf
# 10) P3_20210821H2_213903-225658.cdf
# 11) P3_20210821H2_213903-262058.cdf
# 12) P3_20210827H1_203112-275220.cdf
# 13) P3_20210828H1_200115-221321.cdf
# 14) P3_20210829H1_171201-223719.cdf
# 15) P3_20210925H1_211201-243558.cdf
# 16) P3_20210926H1_220900-255058.cdf
# 17) P3_20210927H1_213003-253558.cdf
# 18) P3_20210929H2_211201-261159.cdf
#
# dropsonde files for 0926
# ...

# %%
# load data
os.chdir( crl_path)
crl_data = crl_list[16]

os.chdir( tdr_path)
inbound_data = tdr_list[0]
outbound_data = tdr_list[1]

# %%
# plot dropsondes + crl data

# this issue is looking a lot better!

warnings.filterwarnings("ignore")
plt.figure(figsize=(20,7))

plt.subplot(211)
make_plots.plot_wvmr( crl_path, crl_list[18], 200, 1500, 'time')
plt.title( "CRL WVMR Measurements of Hurricane Sam, 9/29/21, Eye 2")
make_plots.plot_sondes( crl_path, crl_list[18], sonde_path_0929, 'mr')
make_plots.plot_sondes( crl_path, crl_list[18], sonde_path_0930, 'mr')

plt.subplot(212)
make_plots.plot_wvmr( crl_path, crl_list[18], 2100, 3800, 'time')
plt.title( "CRL WVMR Measurements of Hurricane Sam, 9/29/21, Eye 3")
make_plots.plot_sondes( crl_path, crl_list[18], sonde_path_0929, 'mr')
make_plots.plot_sondes( crl_path, crl_list[18], sonde_path_0930, 'mr')

warnings.filterwarnings("default")

# %%
warnings.filterwarnings("ignore")

plt.figure(figsize=(20,12))


# sam 9/26 eye 1: 200 to 1500. ** this plot looks different!
plt.subplot(311)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 1")
make_plots.plot_wvmr( crl_path, crl_list[16], 0, 2500, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')


# sam 9/26 eye 2: 2350 to 3800
plt.subplot(312)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 2")
make_plots.plot_wvmr( crl_path, crl_list[16], 2350, 3800, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')


# sam 9/26 ey3 3: 4400 to 5600
plt.subplot(313)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 3")
make_plots.plot_wvmr( crl_path, crl_list[16], 4400, 5600, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')

warnings.filterwarnings("default")

# %%
# the same but for temperature
warnings.filterwarnings("ignore")

plt.figure(figsize=(20,12))


# sam 9/26 eye 1: 200 to 1500. ** this plot looks different!
plt.subplot(311)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 1")
make_plots.plot_wvmr( crl_path, crl_list[16], 0, 2500, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')


# sam 9/26 eye 2: 2350 to 3800
plt.subplot(312)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 2")
make_plots.plot_wvmr( crl_path, crl_list[16], 2350, 3800, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')


# sam 9/26 ey3 3: 4400 to 5600
plt.subplot(313)
plt.title("CRL Measurements of Hurricane Sam, 9/26/21, Eye Pass 3")
make_plots.plot_wvmr( crl_path, crl_list[16], 4400, 5600, 'time')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0926, 'mr')
make_plots.plot_sondes( crl_path, crl_list[16], sonde_path_0927, 'mr')

warnings.filterwarnings("default")
