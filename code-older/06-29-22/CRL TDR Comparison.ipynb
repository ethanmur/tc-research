# %%
## last edited: 5/27/22
## Status: Fixed path names to match new directory structure. 
##         Plots TDR and CRL cross sections with the same lat or lon coords.
##         This is working much better! some comparisons look perfect, others seem slightly off still (see 09/26 eye 1)

import numpy as np
import os
import matplotlib.pyplot as plt
import xarray as xr
import datetime 
import warnings

os.chdir(  "/Users/etmu9498/research/code/scripts")
import make_plots

# %%
# view datasets

# paths to data
crl_path = "/Users/etmu9498/research/data/CRL_data/2021"
tdr_path = "/Users/etmu9498/research/data/tdr/sam/nc-files"

# load data to these variables
tdr_list = make_plots.load_tdr(tdr_path)
crl_list = make_plots.load_crl(crl_path)
# Out:
# tdr data files:
# 0) 210926H1_2237_vert_inbound.nc
# 1) 210926H1_2237_vert_outbound.nc
# 2) 210926H1_2350_vert_inbound.nc
# 3) 210926H1_2350_vert_outbound.nc
# 4) 210926H1_2457_vert_inbound.nc
# 5) 210926H1_2457_vert_outbound.nc
# 6) 210927H1_2205_vert_inbound.nc
# 7) 210927H1_2205_vert_outbound.nc
# 8) 210927H1_2320_vert_inbound.nc
# 9) 210927H1_2320_vert_outbound.nc
# 10) 210927H1_2433_vert_inbound.nc
# 11) 210927H1_2433_vert_outbound.nc
# 12) 210929H2_2137_vert_inbound.nc
# 13) 210929H2_2137_vert_outbound.nc
# 14) 210929H2_2249_vert_inbound.nc
# 15) 210929H2_2249_vert_outbound.nc
# 16) 210929H2_2402_vert_inbound.nc
# 17) 210929H2_2402_vert_outbound.nc
# crl data files:
# 0) P3_20210811H1_200000-224759.cdf
# 1) P3_20210812H1_095513-125927.cdf
# 2) P3_20210812H2_212248-235510.cdf
# 3) P3_20210813H1_091801-113558.cdf
# 4) P3_20210816H1_085245-123459.cdf
# 5) P3_20210816H1_090000-102359.cdf
# 6) P3_20210817H1_094204-132058.cdf
# 7) P3_20210818H1_211425-244159.cdf
# ...

# %%
# sam 9/26, eye 1

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[0]
outbound_data = tdr_list[1]
os.chdir( crl_path)
crl_data = crl_list[16]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title( "TDR and CRL, Hurricane Sam 09/26, Eye Pass 1")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-52, -49])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-52, -49])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-52, -49])
# Out:
# (-52.0, -49.0)

# %%
# sam 9/26, eye 2

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[2]
outbound_data = tdr_list[3]
os.chdir( crl_path)
crl_data = crl_list[16]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title( "TDR and CRL, Hurricane Sam 09/26, Eye Pass 2")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-51.5, -49.75])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 2350, 3800, 'lon')
plt.xlim([-51.5, -49.75])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 2350, 3800, 'lon')
plt.xlim([-51.5, -49.75])
# Out:
# (-51.5, -49.75)

# %%
# sam 9/26, eye 3

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[4]
outbound_data = tdr_list[5]
os.chdir( crl_path)
crl_data = crl_list[16]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title( "TDR and CRL, Hurricane Sam 09/26, Eye Pass 3")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-51.75, -50])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 4400, 5600, 'lon')
plt.xlim([-51.75, -50])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 4400, 5600, 'lon')
plt.xlim([-51.75, -50])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# ...

# %%
# sam 9/27 eye 1

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[6]
outbound_data = tdr_list[7]
os.chdir( crl_path)
crl_data = crl_list[17]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title("TDR and CRL, Hurricane Sam 09/27, Eye Pass 1")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-55, -51])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-55, -51])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-55, -51])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# ...

# %%
# sam 9/27 eye 2

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[8]
outbound_data = tdr_list[9]
os.chdir( crl_path)
crl_data = crl_list[17]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title("TDR and CRL, Hurricane Sam 09/27, Eye Pass 2")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lat')
plt.xlim([18, 15])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 2600, 3900, 'lat')
plt.xlim([18, 15])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 2600, 3900, 'lat')
plt.xlim([18, 15])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# ...

# %%
# sam 9/27 eye 3

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[10]
outbound_data = tdr_list[11]
os.chdir( crl_path)
crl_data = crl_list[17]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title("TDR and CRL, Hurricane Sam 09/27, Eye Pass 3")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-54, -52])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 4800, 6500, 'lon')
plt.xlim([-54, -52])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 4800, 6500, 'lon')
plt.xlim([-54, -52])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# ...

# %%
# compare crl and tdr data 9/29

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[12]
outbound_data = tdr_list[13]
os.chdir( crl_path)
crl_data = crl_list[18]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title("TDR and CRL, Hurricane Sam 09/29, Eye Pass 1")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-59.5, -56.5])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-59.5, -56.5])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 0, 2000, 'lon')
plt.xlim([-59.5, -56.5])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:52: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# ...

# %%
# compare crl and tdr data 9/29

# load data
os.chdir( tdr_path)
inbound_data = tdr_list[14]
outbound_data = tdr_list[15]
os.chdir( crl_path)
crl_data = crl_list[18]

plt.figure(figsize=(18,12))
plt.subplot(311)
plt.title("TDR and CRL, Hurricane Sam 09/29, Eye Pass 2")
make_plots.plot_tdr( tdr_path, inbound_data, outbound_data, 'lon')
plt.xlim([-59.5, -56.5])

plt.subplot(312)
make_plots.plot_power_ch1(crl_path, crl_data, 2100, 3800, 'lon')
plt.xlim([-59.5, -56.5])

plt.subplot(313)
make_plots.plot_T(crl_path, crl_data, 2100, 3800, 'lon')
plt.xlim([-59.5, -56.5])
# Out:
# C:\Users\etmu9498\Anaconda3\lib\site-packages\xarray\core\computation.py:733: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:257: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( xaxis, - crl_data.H, crl_pch1, vmin = -25, vmax =-10)
# C:\Users\etmu9498\Desktop\research\scripts\make_plots.py:52: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# ...
