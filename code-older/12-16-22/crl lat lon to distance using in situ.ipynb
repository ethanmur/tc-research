# %%
# important: to get this function to work!!!
# there need to be up to date, new crl and in situ data files
# make these with the "new crl and in situ fiels make" notebook
# if that page isn't working, first make the in situ files.
# then, turn add_dist_coords to False for crl and run that.
# once the crl datasets have been made, run the script again with add_dist_coords set to true
# finally, you should be able to run this script!

import os
os.chdir( "/Users/etmu9498/research/code/scripts/in-situ-scripts")
import in_situ_distance_plots

in_situ_distance_plots.distance_plots( tc='grace', padding=100)

# in_situ_distance_plots.distance_plots_new_heights( tc='all', padding=100)
# Out:
# TC Grace
# Number of crl files: 6
#
# Saving plots to 'in-situ-calculated-distance' folder
# Distance Plots Added
# Plot 1 saved
#
# Distance Plots Added
# Plot 2 saved
#
# Distance Plots Added
# Plot 3 saved
#
# Distance Plots Added
# Plot 4 saved
#
# Distance Plots Added
# Plot 5 saved
#
# Distance Plots Added
# Plot 6 saved
