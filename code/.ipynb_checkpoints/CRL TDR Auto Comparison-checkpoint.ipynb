# %%
import os
os.chdir(  "/Users/etmu9498/research/code/scripts")
import crl_tdr_auto

crl_tdr_auto.plot( tc='grace')
# Out:
# number of tdr files: 22
# Image 1 complete
# Image 2 complete
# update if statement!
