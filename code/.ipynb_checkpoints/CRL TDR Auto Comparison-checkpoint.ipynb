# %%
# %%time

import os
os.chdir(  "/Users/etmu9498/research/code/scripts")
import crl_tdr_auto
import crl_tdr_auto_copy

# crl_tdr_auto.plot( tc='grace', yaxis_zoom=True)

crl_tdr_auto.plot_tdr_only( tc='ida', yaxis_zoom=False)
# Out:
# number of tdr files: 26
# number of outbound points: 95
# number of inbound points: 127
# Image 1 complete
# number of outbound points: 124
# number of inbound points: 120
# Image 2 complete
# number of outbound points: 60
# number of inbound points: 112
# Image 3 complete
# number of outbound points: 18
# number of inbound points: 16
# Image 4 complete
# number of outbound points: 18
# number of inbound points: 21
# Image 5 complete
# number of outbound points: 10
# number of inbound points: 10
# Image 6 complete
# number of outbound points: 110
# number of inbound points: 116
# Image 7 complete
# number of outbound points: 134
# number of inbound points: 145
# Image 8 complete
# number of outbound points: 131
# number of inbound points: 115
# Image 9 complete
# number of outbound points: 129
# number of inbound points: 135
# Image 10 complete
# number of outbound points: 108
# number of inbound points: 165
# ...
