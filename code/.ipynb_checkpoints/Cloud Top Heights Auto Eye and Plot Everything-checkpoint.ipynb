# %%
import os
os.chdir( "/Users/etmu9498/research/code/scripts")
import cloud_height_auto_same_plot_good_data
import cloud_height_auto_same_plot
import plot_all_tc_data

import matplotlib.pyplot as plt
import warnings

# %%
# update font sizes for this plot!
SMALL_SIZE = 14
MEDIUM_SIZE = 16
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize

# %%
# %%time 
# cloud_height_auto_same_plot.plot( tc='henri', tdr_crl=True)
# cloud_height_auto_same_plot_good_data.plot( tc='sam' , eyewall_alg = 'in-situ')

plot_all_tc_data.plot(tc='ida')
# Out:
# TC Ida
# Number of crl files: 4
#
# Eyewall algorithm complete
# TDR Image 1: complete
# CRL Power Image 1: complete
# CRL Temperature Image 1: complete
# In Situ Image 1: complete
# Plot 1 saved
#
# Eyewall algorithm complete
# TDR Image 2: complete
# CRL Power Image 2: complete
# CRL Temperature Image 2: complete
# In Situ Image 2: complete
# Plot 2 saved
#
# Eyewall algorithm complete
# TDR Image 3: complete
# CRL Power Image 3: complete
# CRL Temperature Image 3: complete
# In Situ Image 3: complete
# Plot 3 saved
#
# Eyewall algorithm complete
# TDR Image 4: complete
# CRL Power Image 4: complete
# CRL Temperature Image 4: complete
# In Situ Image 4: complete
# Plot 4 saved
#
# CPU times: total: 27.6 s
# Wall time: 27.6 s
