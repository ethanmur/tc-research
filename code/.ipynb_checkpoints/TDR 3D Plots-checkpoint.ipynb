# %%
## Created: 5/27/22
## last edited: 5/27/22
## Status: Currently not working, but the goal is to be able to plot a 3D reconstruction of TC sam's eyewall and rainbands!

import numpy as np
import os
import matplotlib.pyplot as plt
import xarray as xr
import datetime 
import warnings

os.chdir(  "/Users/etmu9498/research/code/scripts")
import make_plots

# %%
# import and mess with data

os.chdir( "/Users/etmu9498/research/data/tdr/sam/3d")

tdr1 = xr.open_dataset( "210926H1_2237_xy.nc")
tdr2 = xr.open_dataset( "210926H1_2350_xy.nc")
tdr3 = xr.open_dataset( "210926H1_2457_xy.nc")

print( np.shape( tdr1.x))
print( np.shape( tdr1.y))
print( np.shape( tdr1.level))
print( np.shape( tdr1.REFLECTIVITY))
print( np.shape( tdr1.REFLECTIVITY.isel(time=0).isel(y=125)))

# print( tdr1.x)
# print( xr.DataArray.to_numpy( tdr1.x)) # this conversion actually isn't necessary but is cool!
# Out:
# (250,)
# (250,)
# (37,)
# (250, 250, 37, 1)
# (250, 37)

# %%
# plot 2D cross sections to see if things match

plt.pcolormesh( tdr1.x, tdr1.level, tdr1.REFLECTIVITY.isel(time=0).isel(y=120).transpose() )
plt.ylabel( 'Height (km)')
# plt.xlabel( x_label)
plt.grid( 'on')
plt.colorbar(label="Reflectivity ( dBz)")
# Out:
# C:\Users\etmu9498\AppData\Local\Temp/ipykernel_25068/3670694896.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh( tdr1.x, tdr1.level, tdr1.REFLECTIVITY.isel(time=0).isel(y=120).transpose() )

# %%
# trying to plot full 3d figure but not really having any success

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Plot the surface.
surf = ax.plot_surface( tdr1.x, tdr1.y, tdr1.REFLECTIVITY, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# ax.set_zlim(-1.01, 1.01)
# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter('{x:.02f}')
# fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
