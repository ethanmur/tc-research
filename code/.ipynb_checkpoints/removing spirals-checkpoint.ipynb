# %%
import os
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

os.chdir( "/Users/etmu9498/research/code/scripts/save-new-datasets")
import trim_spirals
os.chdir("/Users/etmu9498/research/code/scripts/save-new-datasets")
import save_crl_data
import sys
sys.path.append("/Users/etmu9498/research/code/scripts/save-new-datasets/")
os.chdir(  "/Users/etmu9498/research/code/scripts/save-new-datasets/")
import save_in_situ_data

# %%
# save_crl_data.save_all_crl( add_dist_coords=True)

save_in_situ_data.save_all_in_situ(tcname= 'sam', add_dist_coords=True)
# Out:
# New In Situ File Created and Saved: in-situ-sam-09-26-eye-1.nc
# New In Situ File Created and Saved: in-situ-sam-09-26-eye-2.nc
# New In Situ File Created and Saved: in-situ-sam-09-26-eye-3.nc
# New In Situ File Created and Saved: in-situ-sam-09-27-eye-2.nc
# New In Situ File Created and Saved: in-situ-sam-09-27-eye-3.nc
# New In Situ File Created and Saved: in-situ-sam-09-29-eye-1.nc
# New In Situ File Created and Saved: in-situ-sam-09-29-eye-2.nc

# %%
import os
os.chdir( "/Users/etmu9498/research/code/scripts/in-situ-scripts")
import in_situ_distance_plots

in_situ_distance_plots.distance_plots( tc='henri', padding=100)
# Out:
# TC Henri
# Number of crl files: 5
#
# Saving plots to 'in-situ-calculated-distance' folder
# Distance Plots Added
# Plot 1 saved
#
# Distance Plots Added
# Plot 2 saved
#
# Distance Plots Added
# Plot 3 saved
#
# Distance Plots Added
# Plot 4 saved
#
# Distance Plots Added
# Plot 5 saved

# %%
os.chdir( "/Users/etmu9498/research/data/crl-new")
name1 = 'crl-sam-09-26-eye-3.nc'
name2 = 'crl-grace-08-18-eye-2.nc'
data = xr.open_dataset( name1)
data
# Out:
# <xarray.Dataset>
# Dimensions:             (Time: 1200, layers: 594, time: 1200, H: 594,
#                          Lon: 1200, Lat: 1200)
# Coordinates:
#     time                (Time) float32 ...
#     H                   (layers) float32 ...
#   * Lon                 (Lon) float32 -49.95 -49.95 -49.95 ... -51.72 -51.72
#   * Lat                 (Lat) float32 13.23 13.23 13.23 ... 15.51 15.51 15.51
# Dimensions without coordinates: Time, layers
# Data variables:
#     ProductionDateTime  |S24 ...
#     VersionID           int16 ...
#     LSR                 (time, H) float32 ...
#     WVMR                (time, H) float32 ...
#     T                   (time, H) float32 ...
#     P_ch1               (time, H) float32 ...
# Attributes:
#     global_att:    This file is generated with our Compact Raman lidar measur...
#     global_att1:   The data for each flight is mapped to the same height bin ...
#     global_att2:  For Question about this product, contact Zhien Wang,
#     global_att3:   University of Colorado, Boulder at zhien.wang@colorado.edu
#     global_att4:  This Dataset is a subset of the full CRL dataset for 09-26-...
#     global_att5:  Microphysical spirals in the eyes of TC Grace, 8/18, Pass 2...

# %%
trim_spirals.trim_spirals()
# Out:
# Microphysical Spiral Removed from: P3_20210818H1_211425-244159.cdf
# Microphysical Spiral Removed from: P3_20210821H2_213903-262058.cdf

# %%
'''
print( len( data.time))
print( len( data.Lon))
    

# checking the size of each variable:
var_list = list( data.keys() )
for key in var_list:
    print( np.shape( data[ key]))
'''
os.chdir( "/Users/etmu9498/research/data/crl-spiral-cases")
data = xr.open_dataset( 'P3_20210818H1_211425-244159.cdf')
data
# Out:
# <xarray.Dataset>
# Dimensions:             (time: 1515, layers: 594, Time: 1515, H: 594,
#                          Lon: 1515, Lat: 1515)
# Coordinates:
#   * time                (time) float32 22.8 22.8 22.8 22.8 ... 23.69 23.69 23.69
#     H                   (layers) float32 ...
#     time_distance_axis  (Time) float32 ...
#   * Lon                 (Lon) float32 -82.78 -82.79 -82.79 ... -86.42 -86.42
#   * Lat                 (Lat) float32 19.74 19.75 19.75 ... 19.7 19.69 19.69
# Dimensions without coordinates: layers, Time
# Data variables:
#     ProductionDateTime  |S24 ...
#     VersionID           int16 ...
#     LSR                 (time, H) float32 ...
#     WVMR                (time, H) float32 ...
#     T                   (time, H) float32 ...
#     P_ch1               (time, H) float32 ...
# Attributes:
#     global_att:    This file is generated with our Compact Raman lidar measur...
#     global_att1:   The data for each flight is mapped to the same height bin ...
#     global_att2:  For Question about this product, contact Zhien Wang,
#     global_att3:   University of Colorado, Boulder at zhien.wang@colorado.edu
#     global_att6:  A microphysical spiral present in the middle of this datase...
