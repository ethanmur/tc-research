# %%
# %%time

import os
os.chdir(  "/Users/etmu9498/research/code/scripts")
import crl_tdr_auto
import crl_tdr_auto_copy

crl_tdr_auto.plot( tc='ida-crl', yaxis_zoom=False)

# crl_tdr_auto.plot_tdr_only( tc='grace', yaxis_zoom=False)
# Out:
# number of tdr files: 26
# Image 1 complete
# CPU times: total: 5.48 s
# Wall time: 5.53 s
