# %%
import os
os.chdir( "/Users/etmu9498/research/code/scripts")
import cloud_height_auto_same_plot
import matplotlib.pyplot as plt

# %%
# update font sizes for this plot!
SMALL_SIZE = 12
MEDIUM_SIZE = 12
BIGGER_SIZE = 5000

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize

# not actually working for some reason??
# plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
cloud_height_auto_same_plot.plot( tc='sam', tdr_crl=True)
# Out:
# number of crl files: 8
# TDR Image 1 complete
# -50.6035
# -50.5205
#
# tdr no nan
# crl no nan
# CRL Image 1 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 2 complete
# -50.602
# -50.6808
#
# tdr no nan
# crl no nan
# CRL Image 2 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 3 complete
# -50.6522
# -50.7524
#
# tdr no nan
# crl no nan
# CRL Image 3 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 4 complete
# -52.7912
# -52.4878
#
# tdr no nan
# crl no nan
# CRL Image 4 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 5 complete
# 16.6221
# 16.2178
#
# tdr no nan
# crl no nan
# CRL Image 5 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 6 complete
# -52.8171
# -53.0496
#
# tdr no nan
# crl no nan
# CRL Image 6 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 7 complete
# -57.6532
# -57.884
#
# tdr no nan
# crl no nan
# CRL Image 7 complete
# C:\Users\etmu9498\Anaconda3\envs\tcresearch\lib\site-packages\xarray\core\computation.py:727: RuntimeWarning: invalid value encountered in log10
#   result_data = func(*input_data)
# TDR Image 8 complete
# -58.0694
# -57.7086
#
# tdr no nan
# crl no nan
# CRL Image 8 complete
