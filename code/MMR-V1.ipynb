# %%
import os
import xarray as xr

# %%
os.chdir("/Users/etmu9498/research/data/mmr/")

mmr1 = xr.open_dataset( "NAW_2021_09_26_19_52_00.nc")
mmr2 = xr.open_dataset( "NAW_2021_09_27_00_01_20.nc")

print( mmr1.power_reference)

mmr1
# Out:
# <xarray.DataArray 'power_reference' (time: 992)>
# array([1189.875, 1189.875, 1189.875, ...,    0.   ,    0.   ,    0.   ],
#       dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-09-26T19:52:04 ... 2021-09-26T19:52:0...
# Attributes:
#     long_name:   power_reference
#     units:       Db
#     _fillValue:  -9999.0
# <xarray.Dataset>
# Dimensions:                (time: 992, range: 1296, sweep: 1)
# Coordinates:
#   * time                   (time) datetime64[ns] 2021-09-26T19:52:04 ... 2021...
#   * range                  (range) float32 -29.5 120.4 ... 1.939e+05 1.941e+05
# Dimensions without coordinates: sweep
# Data variables: (12/50)
#     volume_number          int32 ...
#     platform_type          |S14 ...
#     primary_axis           |S8 ...
#     instrument_type        |S8 ...
#     time_coverage_start    |S21 ...
#     time_coverage_end      |S21 ...
#     ...                     ...
#     rcs_reference          float32 ...
# ...
