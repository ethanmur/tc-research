# %%
# overview: the python files held within code/scripts-winter2023 were created to:
# 1: simplify and automate the data processing code for CRL and flight level datasets
# 2: apply the same scripts to 2021 and 2022 data for consistency

# the code below outlines and tests each script!

# %%
# important:
# make sure to download track files for the year of interest if finding radial distance and rmw axes would be helpful!
# processed fl data: 2016 - 2022
# processed track data: 2012 - 2022

# %%
# crl-data-processing folder: 
# save corrected crl datasets
import os
os.chdir( "/Users/etmu9498/research/code/scripts-winter2023/crl-data-processing")
import save_crl_data

# save-crl-data.py
# give it a year (txt), 'all', or an input dictionary like: inputdict['2021'] = ['P3_20210818H1_211425-244159.cdf']

inputdict = {}
# inputdict['2021'] = ["P3_20210811H1_200000-224759.cdf"] # 'P3_20210816H1_085245-123459.cdf'] # ["P3_20210926H1_220900-255058.cdf", "P3_20210927H1_213003-253558.cdf", "P3_20210929H2_211201-261159.cdf"]
inputdict['2022'] = ["P3_20220831H1_093603-142958.cdf", "P3_20220901H1_084204-132352.cdf", "P3_20220903H1_084804-134753.cdf", 
                    "P3_20220904H1_091318-134258.cdf", "P3_20220927H1_094804-125357.cdf", "P3_20221007H1_214018-250934.cdf",
                    "P3_20221008H1_214017-253016.cdfd"]

save_crl_data.save_tcs( tc=inputdict, add_dist_coords={'new_heights': True, 'fl_fields': True, 'rmw': True})
# Out:
# Number of data files to be processed: 7
# 20220831H1
# Corresponding flight level dataset loaded
# In Situ radial distance and rmw axes found
# 3171.605706120455
# short case
# T Interpolated
# 3171.605706120455
# short case
# P_ch1 Interpolated
# 3171.605706120455
# short case
# WVMR Interpolated
# 3171.605706120455
# short case
# LSR Interpolated
# New CRL File Created and Saved: 2022/P3_20220831H1_processed.nc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\file_manager.py:201, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     200 try:
# --> 201     file = self._cache[self._key]
#     202 except KeyError:
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\etmu9498\\research\\data\\CRL_data\\2022\\P3_20220901H1_084204-132352.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 16
#      11 # inputdict['2021'] = ["P3_20210811H1_200000-224759.cdf"] # 'P3_20210816H1_085245-123459.cdf'] # ["P3_20210926H1_220900-255058.cdf", "P3_20210927H1_213003-253558.cdf", "P3_20210929H2_211201-261159.cdf"]
#      12 inputdict['2022'] = ["P3_20220831H1_093603-142958.cdf", "P3_20220901H1_084204-132352.nc", "P3_20220903H1_084804-134753.cdf",
#      13                     "P3_20220904H1_091318-134258.cdf", "P3_20220927H1_094804-125357.cdf", "P3_20221007H1_214018-250934.cdf",
#      14                     "P3_20221008H1_214017-253016.cdfd"]
# ---> 16 save_crl_data.save_tcs( tc=inputdict, add_dist_coords={'new_heights': True, 'fl_fields': True, 'rmw': True})
#
# File ~\research\code\scripts-winter2023\crl-data-processing\save_crl_data.py:41, in save_tcs(tc, add_dist_coords)
#      38 for yeari, yearval in enumerate( yearlist):
#      39     for filei, fileval in enumerate( filelist[ yeari]):
#      40         # use the function below to process the crl data separately!
# ---> 41         crl_data = save_one_crl( yearval, fileval, add_dist_coords=add_dist_coords)
#      43         # make a name for the dataset
#      44         filename = filelist[ yeari][ filei] [ : -18] + "_processed.nc"
#
# File ~\research\code\scripts-winter2023\crl-data-processing\save_crl_data.py:58, in save_one_crl(yearval, crl_name, add_dist_coords)
#      56 crl_path = crl_data_root + yearval
#      57 os.chdir( crl_path)
# ---> 58 crl_data = xr.open_dataset( crl_name)
#      60 # go through every key for add_dist_coords. If any of them are true, we'll need to
#      61 # load the crl's corresponding flight level dataset!
#      62 load_data = False
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\api.py:531, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     519 decoders = _resolve_decoders_kwargs(
#     520     decode_cf,
#     521     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     527     decode_coords=decode_coords,
#     528 )
#     530 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 531 backend_ds = backend.open_dataset(
#     532     filename_or_obj,
#     533     drop_variables=drop_variables,
#     534     **decoders,
#     535     **kwargs,
#     536 )
#     537 ds = _dataset_from_backend_dataset(
#     538     backend_ds,
#     539     filename_or_obj,
#    (...)
#     547     **kwargs,
#     548 )
#     549 return ds
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\netCDF4_.py:555, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     534 def open_dataset(
#     535     self,
#     536     filename_or_obj,
#    (...)
#     551     autoclose=False,
#     552 ):
#     554     filename_or_obj = _normalize_path(filename_or_obj)
# --> 555     store = NetCDF4DataStore.open(
#     556         filename_or_obj,
#     557         mode=mode,
#     558         format=format,
#     559         group=group,
#     560         clobber=clobber,
#     561         diskless=diskless,
#     562         persist=persist,
#     563         lock=lock,
#     564         autoclose=autoclose,
#     565     )
#     567     store_entrypoint = StoreBackendEntrypoint()
#     568     with close_on_error(store):
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\netCDF4_.py:384, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     378 kwargs = dict(
#     379     clobber=clobber, diskless=diskless, persist=persist, format=format
#     380 )
#     381 manager = CachingFileManager(
#     382     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     383 )
# --> 384 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\netCDF4_.py:332, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     330 self._group = group
#     331 self._mode = mode
# --> 332 self.format = self.ds.data_model
#     333 self._filename = self.ds.filepath()
#     334 self.is_remote = is_remote_uri(self._filename)
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\netCDF4_.py:393, in NetCDF4DataStore.ds(self)
#     391 @property
#     392 def ds(self):
# --> 393     return self._acquire()
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\netCDF4_.py:387, in NetCDF4DataStore._acquire(self, needs_lock)
#     386 def _acquire(self, needs_lock=True):
# --> 387     with self._manager.acquire_context(needs_lock) as root:
#     388         ds = _nc4_require_group(root, self._group, self._mode)
#     389     return ds
#
# File ~\Anaconda3\envs\tcresearch\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\file_manager.py:189, in CachingFileManager.acquire_context(self, needs_lock)
#     186 @contextlib.contextmanager
#     187 def acquire_context(self, needs_lock=True):
#     188     """Context manager for acquiring a file."""
# --> 189     file, cached = self._acquire_with_cache_info(needs_lock)
#     190     try:
#     191         yield file
#
# File ~\Anaconda3\envs\tcresearch\lib\site-packages\xarray\backends\file_manager.py:207, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     205     kwargs = kwargs.copy()
#     206     kwargs["mode"] = self._mode
# --> 207 file = self._opener(*self._args, **kwargs)
#     208 if self._mode == "w":
#     209     # ensure file doesn't get overridden when opened again
#     210     self._mode = "a"
#
# File src\netCDF4\_netCDF4.pyx:2353, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\netCDF4\_netCDF4.pyx:1963, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'C:\\Users\\etmu9498\\research\\data\\CRL_data\\2022\\P3_20220901H1_084204-132352.nc'

# %%
# fl-data-processing folder: 
# save smaller, processed flight level datasets
import os
os.chdir( "/Users/etmu9498/research/code/scripts-winter2023/fl-data-processing")
import save_fl_data

# save_fl_data.py- the main function to process fl datasets
# either give it a year (txt), 'all', or an input dictionary like: inputdict['2021'] = ['20210816H1_grace.nc']
# also give it another dictionary specifying which quantities to calculate!
# correct_fl_data_fields.py and find_fl_dists_rmws.py- helper scripts used in the main function

# actually run the function!
inputdict = { '2021':  ['20210811H1_fred.nc']} # [ '20210927H1_sam.nc', '20210929H2_sam.nc'] } # '20210925H1_sam.nc', '20210926H1_sam.nc', '20210927I1_sam.nc', '20210929H1_sam.nc',
inputdict2={'center_dist': True, 'psurf_dist': False, 'rmw': True, 'vars_to_save': 'default'}
save_fl_data.save_tcs( tc=inputdict, add_dist_coords=inputdict2, correct_data='correct')
# Out:
# Number of data files to be processed: 1
# (31052,)
# 2814
# 26987
# <class 'numpy.ndarray'>
# [nan nan nan ... nan nan nan]
# number of flight level data points: 31052
# index = 0
# index = 10000
# index = 20000
# index = 30000
# number of lat nans: 4051
# number of lon nans: 4051
# No wind speed peaks found for this case, so all RMW values will be nans.
# New In Situ File Created and Saved: 20210811H1_fred_processed.nc
# C:\Users/etmu9498/research/code/scripts-winter2023/fl-data-processing\find_fl_dists_rmws.py:34: RuntimeWarning: divide by zero encountered in scalar divide
#   rel_vort.append( vavg / ravg + (vi1 - vi)/(ri1 - ri) )

# %%
# fl-data-compositing folder: 
# make pretty flight level plots and calculate some useful statistics!
import os
import numpy as np
import xarray as xr
import importlib
import sys

sys.path.append( "/Users/etmu9498/research/code/scripts-winter2023/fl-data-compositing")
import auto_flight_level_plots_new_noaa_data as plot
import fl_mean_fields_binned
sys.path.append( "/Users/etmu9498/research/code/scripts-winter2023/fl-data-compositing")
import fl_mean_plots_error

# use this code if things are broken: need to run this cell twice to load the new file :/
importlib.reload( fl_mean_fields_binned)
importlib.reload( fl_mean_plots_error)
# Out:
# <module 'fl_mean_plots_error' from 'C:\\Users/etmu9498/research/code/scripts/plotting\\fl_mean_plots_error.py'>

# %%
# auto_flight_level_plots_new_noaa_data.py (quite the mouthful lol)
# make simple time series plots of the processed flight level data!
# save them to "figures/in-situ-all-data-new-noaa/time-series/year_value"
# inputdict = {'2021': ['20210930H1_sam.nc', '20210930I1_sam.nc']}
plot.plot( tc=inputdict)
# Out:
# Plot 1 saved
#
# Plot 1 saved
#
# Plot 2 saved
#
# Plot 2 saved

# %%
# setup for the compositing plots below
# for these cases, look at flight level data cases that have had RI (+24 kt in 24 hours) recently. 
# use some of the ships methods detailed below to do so!
os.chdir("/Users/etmu9498/research/code/scripts-winter2023/ships-data-munging/")
import group_ships_variables

ri = 30
df = group_ships_variables.group_all( tc='all', make_histograms=True, ri_cond=ri)

# get tc ri names into proper dictionary format
# first, correct the format and put them in a list
intense_list = df['Name'][ np.where( df['Intensification (kt)'].values > ri)[0]].tolist()
for i, val in enumerate( intense_list):
    intense_list[ i] = intense_list[ i][ : -4] + "_processed.nc" # ".nc"
# now, add them to the dict based on year!
# get a list of the years
yearlist = []
filelist = []
for i, val in enumerate( intense_list):
    if len( yearlist) == 0:
        yearlist.append( val[ 0:4])
        filelist.append( [])
    elif not val[0:4] in yearlist:
        yearlist.append( val[ 0:4])
        filelist.append( [])
    else:
        filelist[ -1].append( val )
# make the dictionary!!
inputdict = {}
for i, year in enumerate( yearlist):
    inputdict[ year] = filelist[ i]    

# cases included in the following analysis    
print( inputdict)



############
## actually making the plots now!!
############

# fl_mean_fields_binned.py
# show raw time series plots from rmws 0-1 for all relevant tc cases
# fl_mean_fields_binned.plot_all_eyes( tc=inputdict)

# fl_mean_plots_error.py
# show mean + 95% confidence plots for each variable!
# fl_mean_plots_error.make_plot( tc=inputdict)

# %%
# ships-data-munging folder: make nice plots from SHIPS TC model data, and save some of its info locally
import sys
sys.path.append("/Users/etmu9498/research/code/scripts-winter2023/ships-data-munging/")
import pull_ships_variables
import ships_plots
import group_ships_variables

# pull_ships_variables.py
# automatically make small text files holding shear, etc info!
# these files can be edited pretty easily, and can be created for all years up to and including 2021
inputdict = {}
inputdict['2021'] = [ '20210813I1_grace_processed.nc', '20210925H1_sam_processed.nc']
pull_ships_variables.pull_all_datasets(tc='2018')

# ships_plots.py
# make plots highlighting velocities, surface pressures, and shear values for the duration of a TC!
# really nice for checking out the life cycle of a storm.
# this file also holds the code to make a simple histogram of the intensity, etc distributions in group_ships_variables.py
year = '2021'
# '20210829H1_ida_processed.nc' '20190831H1_dorian_processed.nc' '20210813I1_grace_processed.nc'
fl_name =  '20210925H1_sam_processed.nc'
# ships_plots.make_one_plot( year, fl_name, ri_cond = 30)

# group_ships_variables.py
# print out intensity change statistics for each TC, and return a nice dataframe holding ships intensity, shear stats!
# df = group_ships_variables.group_all( tc='all', make_histograms=True, ri_cond=24)
# Out:
# Loading SHIPS dataset
# SHIPS dataset created
# Number of lines in dataset: 1884145
# flight level data accessed: 20180615H1_michael_processed.nc
#
#
# name: MICH
# date: 0615
# time: 12
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180627H1_michael_processed.nc
#
#
# name: MICH
# date: 0627
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180708H1_chris_processed.nc
#
#
# name: CHRI
# date: 0708
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180708H2_chris_processed.nc
#
#
# name: CHRI
# date: 0708
# time: 00
# wraparound time? True
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180709H1_chris_processed.nc
#
#
# name: CHRI
# date: 0709
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180709H2_chris_processed.nc
#
#
# name: CHRI
# date: 0709
# time: 00
# wraparound time? True
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180718H1_michael_processed.nc
#
#
# name: MICH
# date: 0718
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180719H1_michael_processed.nc
#
#
# name: MICH
# date: 0719
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180731H1_michael_processed.nc
#
#
# name: MICH
# date: 0731
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180817H1_lane_processed.nc
#
#
# name: LANE
# date: 0817
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180818H1_lane_processed.nc
#
#
# name: LANE
# date: 0818
# time: 00
# wraparound time? True
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180820H1_lane_processed.nc
#
#
# name: LANE
# date: 0820
# time: 06
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180820H2_lane_processed.nc
#
#
# name: LANE
# date: 0820
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180821H1_lane_processed.nc
#
#
# name: LANE
# date: 0821
# time: 06
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180821H1_michael_processed.nc
#
#
# name: MICH
# date: 0821
# time: 06
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180822H1_lane_processed.nc
#
#
# name: LANE
# date: 0822
# time: 06
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180822H2_lane_processed.nc
#
#
# name: LANE
# date: 0822
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180824H1_lane_processed.nc
#
#
# name: LANE
# date: 0824
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180903H1_gordon_processed.nc
#
#
# name: GORD
# date: 0903
# time: 00
# wraparound time? True
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180904H1_gordon_processed.nc
#
#
# name: GORD
# date: 0904
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180904H2_gordon_processed.nc
#
#
# name: GORD
# date: 0904
# time: 00
# wraparound time? True
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180907H1_florence_processed.nc
#
#
# name: FLOR
# date: 0907
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180908H1_florence_processed.nc
#
#
# name: FLOR
# date: 0908
# time: 18
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180909H1_florence_processed.nc
#
#
# name: FLOR
# date: 0909
# time: 18
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180910H1_florence_processed.nc
#
#
# name: FLOR
# date: 0910
# time: 18
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180912H1_isaac_processed.nc
#
#
# name: ISAA
# date: 0912
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180913H1_isaac_processed.nc
#
#
# name: ISAA
# date: 0913
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180914H1_isaac_processed.nc
#
#
# name: ISAA
# date: 0914
# time: 18
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20180915H1_isaac_processed.nc
#
#
# name: ISAA
# date: 0915
# time: 06
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20180915H2_isaac_processed.nc
#
#
# name: ISAA
# date: 0915
# time: 18
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.
#
# flight level data accessed: 20181008H1_michael_processed.nc
#
#
# name: MICH
# date: 1008
# time: 00
# wraparound time? True
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20181009H1_michael_processed.nc
#
#
# name: MICH
# date: 1009
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20181009H2_michael_processed.nc
#
#
# name: MICH
# date: 1009
# time: 00
# wraparound time? True
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20181011H1_michael_processed.nc
#
#
# name: MICH
# date: 1011
# time: 12
# wraparound time? False
# Important SHIPS data saved under data/ships-output/
# flight level data accessed: 20181012H1_michael_processed.nc
#
#
# name: MICH
# date: 1012
# time: 12
# wraparound time? False
# No SHIPS dataset found for this case. Skipping to the next case.

# %%
# look at processed data: nice to have an example ready!
import xarray as xr
os.chdir( "/Users/etmu9498/research/data/in-situ-noaa-processed/2018/")
data = xr.open_dataset( '20180615H1_michael_processed.nc')
data
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 17906)
# Coordinates:
#   * time            (time) float64 7.869 7.87 7.87 7.87 ... 12.84 12.84 12.84
# Data variables: (12/15)
#     HT.d            (time) float32 ...
#     THETA.d         (time) float32 ...
#     THETAV.d        (time) float32 ...
#     WS.d            (time) float32 ...
#     WD.d            (time) float32 ...
#     UWZ.d           (time) float32 ...
#     ...              ...
#     TA.d            (time) float32 ...
#     PSURF.d         (time) float32 ...
#     LATref          (time) float32 ...
#     LONref          (time) float32 ...
#     rmw             (time) float64 ...
#     center_dist     (time) float64 ...
# Attributes:
#     Author:       Created by NOAA HRD. Link to data: https://www.aoml.noaa.go...
#     Editor:       Edited by: Ethan Murray (etmu9498@colorado.edu)
#     Attribution:  This Dataset is based off the dataset 20180615H1_michael.nc...
#     Note:         These data have been limited to P-3 heights between 2.5 km ...

# %%
# cloud-top-height-stats folder:
# find cloud top heights within user specified eyewall ranges.
# all metadata and helper scripts should be isolated within the scripts-winter2023 folder!

# all these functions are run in a separate notebook! notebooks-winter2023/"2022 eyewall determinations.ipynb"
