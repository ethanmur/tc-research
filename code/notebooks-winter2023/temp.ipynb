# %%
import os
# fl-data-compositing folder: make pretty flight level plots and calculate some useful statistics!
os.chdir( "/Users/etmu9498/research/code/scripts-winter2023/fl-data-compositing")
#import fl_time_series_new_noaa_data as plot
import auto_flight_level_plots_new_noaa_data as plot

plot.plot( tc='2018')
# Out:
# Total Number of plots to be created: 35
#
# Plot 1 saved
#
# Plot 2 saved
#
# Plot 3 saved
#
# Plot 4 saved
#
# Plot 5 saved
#
# Plot 6 saved
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       4 #import fl_time_series_new_noaa_data as plot
#       5 import auto_flight_level_plots_new_noaa_data as plot
# ----> 7 plot.plot( tc='2018')
#
# File ~\research\code\scripts-winter2023\fl-data-compositing\auto_flight_level_plots_new_noaa_data.py:270, in plot(tc, max_v_requirement, window, method, timelim, ylims)
#     268 p = fl_data['PSURF.d']
#     269 maxh = 1023.0 # add some padding to max pressure of 1013.0 hpa
# --> 270 minh = np.nanmin( p[ np.where( p > 850.0)])
#     271 ax4.set_ylim( [minh - 10.0, maxh])# [2900, 3300]) # use 2500 m as a lower limit for strong tcs to see full height dip!
#     273 ax4.set_xlim(ax1lims)
#
# ...
