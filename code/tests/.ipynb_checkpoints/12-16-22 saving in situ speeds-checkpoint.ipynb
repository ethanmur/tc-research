# %%
import os
os.chdir( "/Users/etmu9498/research/code/scripts/in-situ-scripts")
import save_in_situ_as_netcdf as save
import load_in_situ_data as load
os.chdir( "/Users/etmu9498/research/code/scripts")
import make_plots

# results: the top function might be a little faster, but not by much :/ still need to figure out why it takes so long to 
# load in situ data

# %%
save.save_as_netcdf()
# Out:
# Pandas dataset loaded for file 0
# Pandas dataset trimmed for file 0
# In Situ File Created and Saved: 20210527H1_iwg1.nc
# Pandas dataset loaded for file 1
# Pandas dataset trimmed for file 1
# In Situ File Created and Saved: 20210713H1_iwg1.nc
# Pandas dataset loaded for file 2
# Pandas dataset trimmed for file 2
# In Situ File Created and Saved: 20210716H1_iwg1.nc
# Pandas dataset loaded for file 3
# Pandas dataset trimmed for file 3
# In Situ File Created and Saved: 20210811H1_iwg1.nc
# Pandas dataset loaded for file 4
# Pandas dataset trimmed for file 4
# In Situ File Created and Saved: 20210812H1_iwg1.nc
# Pandas dataset loaded for file 5
# Pandas dataset trimmed for file 5
# In Situ File Created and Saved: 20210812H2_iwg1.nc
# Pandas dataset loaded for file 6
# Pandas dataset trimmed for file 6
# In Situ File Created and Saved: 20210813H1_iwg1.nc
# Pandas dataset loaded for file 7
# Pandas dataset trimmed for file 7
# In Situ File Created and Saved: 20210816H1_iwg1.nc
# ...

# %%
flight_path = "/Users/etmu9498/research/data/in-situ"
flight_list = make_plots.load_flight_level( flight_path, print_files=False)

for i in range( len( flight_list)):
    load.load_in_situ( flight_path, flight_list[ i], sample_step_size= 1)
    print("data file " + str( i) + ' loaded')
# Out:
# data file 0 loaded
# data file 1 loaded
# data file 2 loaded
# data file 3 loaded
# data file 4 loaded
# data file 5 loaded
# data file 6 loaded
# data file 7 loaded
# data file 8 loaded
# data file 9 loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       2 flight_list = make_plots.load_flight_level( flight_path, print_files=False)
#       4 for i in range( len( flight_list)):
# ----> 5     load.load_in_situ( flight_path, flight_list[ i], sample_step_size= 1)
#       6     print("data file " + str( i) + ' loaded')
#
# File ~\research\code\scripts\in-situ-scripts\load_in_situ_data.py:53, in load_in_situ(flight_path, flight_number, sample_step_size)
#      50 in_situ_data_trim['time'] = [dt_object.time() for dt_object in in_situ_data_trim.dt ]
#      52 # convert from pandas to xarray
# ...
