# %%
import os
os.chdir(  "/Users/etmu9498/research/code/scripts/plotting")
import rmw_inner_outer_stats as stats

stats.plot_all(tc='all', test_type='intensity', binwidth=.025, smoothwidth=20, plot_raw=False)

# cloud heights that need to be fixed for this case for some reason: grace 8/17 eyes 2 and 3, 8/18 eyes 2 and 3,
# Out:
# TC Fred
# Number of crl files: 7
#
#
# TC Grace
# Number of crl files: 11
#
#
# TC Henri
# Number of crl files: 5
#
#
# TC Ida
# Number of crl files: 5
#
#
# TC Sam
# Number of crl files: 7
#
#
# All height statistics for TDs:
# Number of data points:  2235
# Height value range:     0.0010100000001154186 km to 3.4230400000000043 km
# Mean confidence outputs:
# mean = 1.9099620262794386
# confidence = 0.75
# low bound = 1.8841822134866033
# high bound = 1.9357418390722738
# Single draw confidence outputs:
# low bound = 0.9303838987234877
# high bound = 2.8895401538353895
#
#
# Number of data points:  2235
# Height value range:     0.0010100000001154186 km to 3.4230400000000043 km
# Mean confidence outputs:
# mean = 1.9099620262794386
# confidence = 0.95
# low bound = 1.8660192586837407
# high bound = 1.9539047938751364
# Single draw confidence outputs:
# low bound = 0.24095791082949747
# high bound = 3.5789661417293797
#
#
# Number of data points:  2235
# ...
