# %%
# updates in v3 code: have users choose input variables, and automatically calc mean, etc quantities with less user input!

# 1/29/23 edit: this is actually kinda complicated :/ I edited some of the code below, but not all of it.
# the lists within lists were becoming increasingly complex, and I think that this might not be the best solution...

# I think that a pandas solution would be much simpler and more elegant! look into

# %%
# try to make this code work without accessing any metadata / preprocessed data!
# it would be very convenient to be able to plug 2022, etc raw data into this algorithm and have it work.

# although, I'm not sure how I'd set up a window for these examples without accessing metadata... maybe there would be an
# anamalous pressure drop outside the inner core for weaker TCs
# for now, I'm just gonna try to get this to work for a strong TC with a well defined lowest central pressure, and 
# expand the code to other, less clear examples later!

# %%
# try to pick out minimum pressure values using raw and smoothed data: any differences?

# ways to find pressure minima:
# 1) use a threshold depending on the strnegth of the tc (strength can be found by finding the max ws!) to sort for only
# certain pressure minima ( less than 960 hPa for SH, less than 990 hPa for TS, etc). This will eliminate false peaks?

# 2) use some find_peaks trickery to isolate the correct central pressure peaks! Again, this might require filtering based
# on strength

# 3) use windows determined by crl data, and just look for the lowest pressure over that window -> simpler, but it 
# is significantly slower :(

# 4) use a self organizing map or another fancy machine learning algorithm to sort and find tc centers???

# %%
# import...
import numpy as np
import xarray as xr
import os
import matplotlib.pyplot as plt
from matplotlib import cm

import warnings
import pandas as pd
from scipy.signal import find_peaks

os.chdir("/Users/etmu9498/research/code/scripts")
import make_plots_new_heights
import make_plots
import tc_metadata
import helper_fns

os.chdir("/Users/etmu9498/research/code/scripts/in-situ-scripts")
import load_in_situ_data

os.chdir("/Users/etmu9498/research/code/scripts/plotting")
import rmw_inner_outer_stats as extra_stats # confidence interval function resides here!

# %%
# taken from 'in-situ-scripts/save_in_situ_as_nedcdf.py'
# old function is way too clunky and slow, this one works much better!

def tofloat( dataset):
    # this snippet turns all relevant quantities from strings into floats
    # add more fields here if needed!
    keylist = [ 'time', 'WS.d', 'WD.d', 'UWZ.d', 'ASfmrRainRate.1', 'LATref', 'LONref', 'TAS.d', 'PSURF.d', 
               'HT.d', 'PITCHref', 'ROLLref']
    # create an empty version of the xarray dataset
    datasetnew = dataset.copy()
    datasetnew = datasetnew[ []]

    for key in keylist:
        datasetnew[ key] = dataset[ key].astype( float)
    return datasetnew

# %%
######################
## Load and find rmw values for each TC!
######################

#####################
## this code has been updated and works, but all the code below hasn't been!!!
#####################


# load 2021 in situ data
fl_path = "/Users/etmu9498/research/data/in-situ/"
fl_list = make_plots.load_flight_level( fl_path, print_files=False)

# for this notebook, do this for every case from TC Sam! 
dataset_numbers = [20, 29, 31, 32, 34] # this final dataset looks really bad :( excluded from this analysis! 35]
dates = ['08-29', "09-25", "09-26", "09-27", "09-29"] # , "09-30"]
names = ['Ida', 'Sam', 'Sam', 'Sam', 'Sam']


#############################
# new code
#############################

# input variables
input_vars = [ 'time', 'WS.d', 'UWZ.d']

# output variable list: all empty and the length of the input list
output_totals = [ ]
for i in range( len( input_vars)):
    output_totals.append( [])

# save rmw_total in its own list because we'll always need it and it's really important!!
rmw_total = []

# helper variable used to count the number of eye passes
pass_counter = 0
# repeat these steps for every input date's dataset
for i in range( len( dataset_numbers)):
    data_number = dataset_numbers[ i]
    fl_txt = fl_list[ data_number] # original case: 31
    fl_data = load_in_situ_data.load_in_situ( fl_path, fl_txt)
    dataset = tofloat( fl_data)
    print( "Dataset " + str( i) + " loaded")
                

    # smooth wind speeds and surface pressures- more realistic peaks
    window = 30 # seconds
    spd_avg = pd.Series( dataset['WS.d']).rolling(window=window, min_periods=1, center=True).mean()
    
    # test 1: wind speed threshold with no eyewall limits
    # find max TC strength from averaged wind fields- all eye passes from this tc
    vmax = np.nanmax( spd_avg)
    # check based on max TC strength
    if vmax > 50:
        print( "SH case")
        peak_min = 40 # m/s
    else: 
        print( "Weaker case: update if statement for different peak_min behavior!")
        peak_min = 40 # m/s

    # find max vel peaks using the min peak height (defined above) for this intensity
    vpeaks = find_peaks( x=spd_avg, height=peak_min, prominence=10)

    
    ####################
    # new code
    # repeat this step for every variable in the input list!
    ####################
    for input_ind in range( len( input_vars)):
        # temp variable that will be appended onto the new list
        # like vtrim, wtrim from old code
        var_trim = []
        
        # do step = 2 to skip the second index for each eyewall!
        for vind in range( int( len(vpeaks[0]) / 2 ) ):

            left_eyewall_ind = vpeaks[0][ 2* vind]
            right_eyewall_ind = vpeaks[0][2 * vind + 1]

            # find the corresponding times
            ws_ind = np.nanargmin( spd_avg[ left_eyewall_ind:right_eyewall_ind])

            # make an rmw axis stretching from one eyewall to the other!
            # they will have an unequal number of data points to conserve the time axis :)
            len1 = ws_ind
            len2 = right_eyewall_ind - ( left_eyewall_ind + ws_ind)

            # add the v and w values for convenience
            var_trim.append( ws[ left_eyewall_ind : right_eyewall_ind])

            pass_counter += 1

            # only append rmw values for the last case
            if input_ind == len( input_vars) - 1:
                ws_rmw.append( np.concatenate( [ np.linspace( -1, 0, num=len1, endpoint=False), np.linspace( 0, 1, num=len2) ] ))

        # append the trimmed variable to the overall list
        output_totals[ input_ind] = var_trim

    # append rmw at the end to its own fancy list
    rmw_total.append( ws_rmw)
    

print( len( output_totals))
print( len( output_totals[ 0]))
print( len( rmw_total))

print( output_totals)
# Out:
# Dataset 0 loaded
# SH case
# Dataset 1 loaded
# SH case
# Dataset 2 loaded
# SH case
# Dataset 3 loaded
# SH case
# Dataset 4 loaded
# SH case
# 3
# 4
# 5
# [[array([58.96, 56.61, 55.05, 56.9 , 57.34, 52.84, 54.75, 56.83, 61.56,
#        64.06, 64.56, 68.78, 69.03, 64.33, 62.41, 55.17, 53.2 , 50.98,
#        49.96, 49.05, 50.63, 49.54, 48.1 , 49.77, 53.35, 50.12, 44.44,
#        41.87, 43.5 , 45.64, 45.74, 45.19, 44.  , 43.14, 42.56, 43.9 ,
#        41.94, 42.33, 43.97, 46.23, 47.47, 47.43, 46.63, 47.78, 45.75,
#        48.49, 48.25, 47.75, 48.38, 47.17, 45.61, 44.57, 44.8 , 45.27,
#        46.63, 48.72, 47.97, 47.62, 47.22, 47.43, 47.28, 46.25, 46.3 ,
#        46.18, 46.77, 47.46, 47.09, 47.01, 47.64, 47.08, 46.7 , 45.79,
#        45.45, 45.51, 45.32, 46.1 , 46.71, 45.86, 44.67, 43.73, 44.16,
#        43.71, 46.69, 46.19, 47.39, 47.8 , 47.47, 47.36, 47.84, 48.36,
#        48.61, 48.28, 48.07, 48.52, 48.56, 48.46, 47.92, 47.45, 48.15,
#        47.9 , 46.58, 45.68, 44.98, 45.23, 44.7 , 45.22, 45.35, 44.97,
#        45.21, 45.11, 45.34, 45.15, 45.53, 46.35, 46.95, 46.96, 46.99,
#        47.11, 46.25, 45.9 , 45.76, 44.8 , 44.65, 44.73, 44.53, 43.27,
#        42.54, 42.97, 42.63, 41.75, 41.28, 41.64, 41.54, 41.07, 40.93,
#        41.12, 41.12, 40.98, 41.13, 41.03, 40.3 , 40.55, 40.75, 41.08,
#        41.26, 41.14, 41.27, 40.58, 39.74, 38.49, 38.29, 36.77, 36.45,
#        36.22, 35.82, 34.8 , 34.45, 34.35, 34.28, 33.4 , 33.18, 32.91,
#        33.09, 32.52, 32.53, 32.56, 32.17, 32.06, 32.17, 32.6 , 32.03,
#        31.89, 31.42, 31.26, 30.96, 31.12, 30.5 , 31.08, 30.89, 30.92,
#        30.72, 30.02, 29.64, 28.32, 27.38, 26.93, 26.11, 25.71, 25.69,
#        25.94, 25.57, 24.95, 25.17, 25.9 , 25.06, 25.62, 25.47, 26.39,
#        25.79, 25.75, 25.74, 24.86, 24.44, 24.36, 24.42, 24.48, 24.4 ,
#        24.08, 23.63, 23.28, 22.59, 21.79, 21.2 , 21.01, 20.85, 20.71,
#        19.62, 18.55, 17.87, 17.58, 17.41, 17.3 , 16.63, 16.86, 16.63,
#        16.05, 16.38, 16.3 , 16.13, 15.89, 15.63, 15.6 , 15.44, 15.15,
#        14.89, 14.73, 14.51, 13.77, 13.17, 13.04, 12.68, 12.03, 11.92,
#        11.64, 11.66, 11.07, 10.92, 11.13, 10.93, 10.85, 10.63, 10.51,
#        10.03,  9.59,  9.39,  9.46,  9.23,  9.67,  9.64,  9.57,  9.39,
#         9.35,  9.21,  8.94,  8.27,  7.84,  7.44,  7.3 ,  7.03,  6.91,
#         6.71,  6.88,  6.8 ,  6.47,  6.26,  6.19,  5.99,  5.98,  5.85,
#         5.98,  5.99,  6.08,  5.81,  5.29,  4.84,  4.41,  4.51,  4.4 ,
#         4.15,  4.11,  4.62,  3.76,  3.66,  4.36,  4.64,  4.46,  4.08,
#         3.97,  3.87,  2.85,  2.46,  3.56,  3.72,  3.26,  2.64,  2.63,
#         2.34,  2.55,  2.81,  2.38,  2.27,  2.17,  2.29,  2.31,  2.51,
#         2.83,  2.8 ,  2.91,  2.83,  2.8 ,  2.92,  3.07,  3.17,  3.35,
#         3.78,  4.77,  4.76,  4.62,  4.92,  5.08,  4.85,  4.87,  5.34,
#         5.72,  5.58,  5.5 ,  5.34,  5.63,  5.3 ,  5.44,  5.6 ,  5.68,
#         5.55,  6.23,  6.76,  6.84,  7.41,  7.53,  8.35,  8.13,  8.41,
#         9.76,  9.83,  7.97,  8.03,  9.52,  9.7 ,  9.53,  8.99,  9.11,
#        11.19, 11.47, 11.86, 12.81, 12.68, 12.78, 13.02, 13.49, 13.46,
#        13.74, 13.91, 13.67, 13.71, 13.65, 13.42, 13.49, 13.76, 13.47,
#        13.43, 13.65, 13.7 , 13.65, 13.45, 14.14, 14.4 , 13.89, 14.41,
#        14.39, 14.26, 14.21, 14.49, 14.65, 14.88, 15.01, 15.4 , 16.05,
#        16.13, 16.15, 16.53, 16.66, 16.8 , 17.03, 17.45, 18.27, 18.54,
#        18.62, 19.08, 19.5 , 19.71, 20.77, 21.19, 21.4 , 21.93, 22.89,
#        23.59, 23.57, 23.7 , 24.45, 25.  , 25.62, 25.61, 26.26, 27.13,
#        28.43, 28.16, 28.52, 28.18, 28.36, 29.63, 29.23, 29.49, 32.47,
#        33.24, 33.13, 32.99, 33.34, 33.88, 34.67, 34.72, 34.66, 35.81,
#        36.55, 35.97, 36.44, 37.16, 38.19, 37.91, 38.38, 38.71, 39.37,
#        39.69, 40.91, 40.85, 41.13, 41.27, 41.07, 41.29, 41.56, 41.53,
#        41.69, 41.77, 41.86, 42.32, 42.76, 43.27, 43.28, 43.08, 43.04,
#        42.94, 42.8 , 43.1 , 42.8 , 42.53, 42.7 , 42.88, 43.32, 42.96,
#        43.16, 43.4 , 43.04, 43.03, 43.77, 44.06, 43.87, 44.11, 43.68,
#        41.98, 42.18, 42.2 , 42.19, 42.01, 41.84, 42.79, 42.27, 42.38,
#        42.39, 42.07, 41.53, 41.48, 41.38, 41.41, 41.83, 41.96, 41.82,
#        41.63, 41.5 , 41.47, 41.49, 41.65, 41.55, 41.96, 42.23, 42.44,
#        42.97, 43.18, 43.21, 43.36, 43.19, 43.17, 43.33, 43.6 , 43.26,
#        43.67, 43.53, 43.9 , 44.56, 44.61, 44.6 , 44.05, 44.25, 44.79,
#        45.49, 45.28, 46.1 , 46.56, 46.17, 46.68, 45.86, 46.07, 46.17,
#        46.13, 47.01, 48.65, 47.18, 46.81, 46.85, 46.85, 46.28, 47.24,
#        47.4 , 46.38, 47.7 , 50.08, 49.97, 47.77, 47.64, 50.35, 49.31,
#        49.06, 51.59, 53.82, 54.18, 53.24, 52.44, 54.1 , 54.74, 54.59,
#        55.16, 54.38, 55.58, 55.4 , 55.38, 55.92, 56.5 , 56.89, 56.15,
#        57.11, 60.27, 61.45, 57.84, 59.92, 65.22, 67.78, 67.07, 62.79,
#        64.1 , 63.43, 63.27, 63.06, 61.96, 61.69, 60.54]), array([67.77, 69.79, 69.35, 70.66, 66.77, 62.15, 66.48, 70.05, 71.17,
#        73.84, 63.46, 63.38, 62.29, 60.17, 61.4 , 58.06, 55.12, 52.07,
#        53.84, 56.24, 55.93, 53.45, 54.18, 51.2 , 46.38, 49.82, 48.92,
#        47.77, 48.08, 48.43, 50.57, 45.21, 45.91, 45.25, 45.19, 49.23,
#        41.13, 39.63, 38.18, 39.94, 40.25, 40.07, 39.82, 39.9 , 39.29,
#        39.22, 38.75, 40.47, 38.81, 39.45, 42.13, 44.58, 43.91, 43.73,
#        42.52, 42.06, 42.53, 43.39, 43.43, 42.84, 42.62, 43.15, 43.27,
#        43.49, 43.13, 42.78, 42.79, 43.13, 42.56, 42.53, 43.01, 43.77,
#        44.19, 44.21, 43.84, 42.59, 42.54, 42.56, 42.  , 41.13, 40.75,
#        42.44, 44.88, 45.39, 42.6 , 41.21, 42.86, 44.13, 43.46, 43.19,
#        43.46, 42.57, 43.48, 43.27, 43.27, 41.88, 41.93, 42.55, 40.49,
#        40.52, 41.66, 41.49, 41.47, 40.49, 41.05, 41.31, 40.  , 39.22,
#        38.21, 37.98, 37.82, 36.46, 35.54, 35.08, 35.02, 35.09, 35.13,
#        34.91, 34.08, 34.26, 33.82, 32.95, 32.23, 30.47, 31.59, 32.05,
#        31.5 , 31.64, 33.54, 33.66, 32.65, 33.33, 33.13, 32.31, 32.28,
#        32.1 , 30.96, 30.52, 31.5 , 30.81, 29.91, 28.72, 27.75, 26.53,
#        27.24, 27.37, 26.92, 27.2 , 26.46, 25.97, 25.66, 24.87, 24.43,
#        22.88, 22.6 , 22.55, 22.04, 21.13, 20.8 , 20.49, 19.93, 19.11,
#        18.52, 17.93, 17.34, 17.36, 17.24, 16.89, 16.76, 16.84, 17.06,
#        17.07, 16.6 , 16.41, 15.87, 14.49, 14.66, 14.7 , 15.07, 14.41,
#        14.26, 14.51, 14.96, 15.  , 14.96, 14.82, 14.59, 14.23, 13.25,
#        12.86, 11.97, 11.65, 11.33, 10.82, 10.49, 10.4 , 10.01,  9.79,
#        10.02,  9.75,  9.19,  9.02,  8.63,  8.27,  7.92,  7.58,  7.48,
#         7.5 ,  6.91,  6.31,  5.92,  5.92,  6.06,  5.7 ,  5.11,  4.92,
#         5.2 ,  4.6 ,  4.22,  3.91,  4.29,  4.39,  4.01,  3.47,  3.01,
#         2.69,  2.41,  2.32,  2.54,  3.06,  2.83,  2.36,  2.26,  2.52,
#         2.09,  2.26,  2.36,  2.68,  1.92,  2.11,  2.28,  2.17,  1.66,
#         2.13,  1.23,  0.38,  1.  ,  1.34,  2.22,  2.33,  3.59,  2.29,
#         2.28,  1.74,  1.52,  2.25,  2.72,  2.72,  2.68,  3.09,  2.92,
#         2.53,  2.57,  2.98,  2.88,  3.31,  3.41,  3.76,  3.77,  3.91,
#         3.87,  3.67,  3.43,  3.55,  3.8 ,  3.9 ,  3.63,  4.15,  4.47,
#         4.71,  4.76,  4.96,  4.92,  5.25,  5.47,  5.75,  6.3 ,  6.73,
#         7.19,  7.1 ,  7.35,  7.57,  7.53,  7.63,  7.9 ,  7.86,  7.97,
#         8.12,  8.42,  8.36,  9.39,  9.75,  9.86, 10.16, 10.52, 10.74,
#        10.83, 10.92, 10.94, 10.76, 10.86, 10.98, 11.37, 12.04, 12.38,
#        12.98, 14.11, 14.24, 14.15, 15.23, 16.45, 16.28, 16.58, 16.64,
#        17.55, 18.34, 18.82, 18.95, 19.84, 21.21, 21.39, 21.61, 21.98,
#        21.65, 21.77, 21.97, 21.96, 22.28, 22.41, 22.4 , 22.92, 22.98,
#        23.56, 23.87, 23.31, 23.07, 22.68, 24.4 , 23.94, 24.16, 25.35,
#        24.93, 24.37, 25.21, 25.29, 25.62, 25.64, 26.47, 26.96, 27.97,
#        28.29, 28.11, 27.77, 27.65, 28.34, 28.78, 28.79, 29.69, 30.4 ,
#        30.  , 30.27, 30.72, 31.23, 31.24, 31.25, 32.11, 32.37, 32.99,
#        33.24, 33.84, 34.88, 35.61, 36.56, 37.19, 37.39, 38.99, 38.88,
#        40.08, 40.92, 40.61, 40.52, 40.36, 40.76, 41.06, 41.76, 41.79,
#        41.54, 41.63, 41.75, 41.26, 40.93, 40.84, 40.36, 40.54, 40.98,
#        41.37, 41.02, 41.11, 41.52, 41.77, 41.68, 41.66, 42.22, 42.92,
#        43.25, 43.37, 43.37, 43.71, 43.92, 43.83, 43.93, 44.29, 44.49,
#        44.5 , 44.88, 44.8 , 44.81, 45.08, 45.19, 45.58, 45.86, 46.43,
#        47.03, 46.7 , 46.57, 46.88, 47.14, 47.13, 47.09, 47.38, 47.19,
#        47.39, 47.21, 47.12, 47.39, 47.15, 47.46, 47.27, 47.29, 47.48,
#        47.33, 47.67, 47.5 , 47.24, 47.21, 47.15, 46.76, 46.76, 46.61,
#        46.42, 47.13, 48.09, 48.69, 49.54, 49.95, 49.43, 51.12, 52.9 ,
#        52.96, 51.88, 52.08, 55.12, 54.49, 53.95, 55.64, 55.59, 55.48,
#        55.52, 54.88, 55.89, 55.65, 56.88, 56.28, 57.14, 55.32, 58.36,
#        60.4 , 60.14, 60.02, 59.91, 60.21, 59.94, 61.59, 61.54, 61.57,
#        60.24, 61.09, 62.95, 58.71, 58.51, 59.76, 60.55, 62.12, 61.46,
#        62.34, 61.86, 61.35, 61.41, 61.98, 62.62, 62.55, 61.9 , 63.38,
#        63.78, 62.38, 62.72, 64.16, 64.06, 65.  , 65.71, 64.28, 64.69,
#        64.38, 64.07, 63.57, 64.66]), array([65.24, 66.02, 66.38, 66.59, 66.39, 67.06, 68.13, 68.74, 69.24,
#        69.19, 68.28, 68.65, 68.31, 68.55, 68.45, 67.77, 66.88, 65.56,
#        64.91, 63.74, 60.13, 59.03, 60.8 , 60.75, 61.97, 63.81, 63.55,
#        60.86, 59.99, 58.05, 58.9 , 59.6 , 58.16, 58.15, 56.63, 53.71,
#        54.56, 54.22, 55.42, 55.83, 55.61, 55.  , 55.05, 54.6 , 54.76,
#        55.03, 55.31, 55.39, 55.94, 56.07, 56.22, 54.9 , 54.98, 55.1 ,
#        55.03, 54.24, 53.7 , 53.16, 52.39, 52.27, 52.24, 51.36, 50.76,
#        50.35, 50.48, 49.57, 49.39, 49.01, 48.02, 46.91, 46.5 , 46.11,
#        46.25, 45.55, 45.14, 46.97, 47.19, 45.84, 44.63, 44.82, 45.01,
#        45.19, 45.1 , 44.54, 43.6 , 42.54, 42.1 , 41.72, 41.43, 41.26,
#        40.71, 40.1 , 39.04, 38.83, 39.  , 38.82, 39.12, 38.93, 38.04,
#        38.3 , 37.86, 36.89, 37.03, 35.79, 35.5 , 34.96, 34.85, 34.53,
#        34.39, 34.11, 34.42, 34.02, 33.45, 33.27, 33.16, 33.02, 33.44,
#        33.27, 33.05, 33.49, 33.48, 33.37, 33.32, 33.33, 33.26, 32.9 ,
#        32.43, 31.95, 31.69, 31.56, 31.12, 30.51, 30.03, 29.69, 29.95,
#        29.76, 29.47, 28.9 , 28.98, 28.87, 28.62, 28.4 , 28.3 , 28.05,
#        28.  , 28.5 , 27.65, 27.01, 26.51, 26.89, 25.74, 24.7 , 25.15,
#        25.15, 24.86, 24.73, 24.96, 25.29, 24.94, 24.88, 24.93, 24.23,
#        23.98, 23.93, 23.81, 23.53, 23.46, 22.84, 22.83, 22.4 , 22.29,
#        21.75, 21.69, 21.36, 21.16, 20.82, 20.28, 19.67, 19.49, 19.18,
#        18.94, 18.81, 18.7 , 18.18, 18.15, 18.  , 17.99, 17.73, 17.29,
#        16.44, 16.  , 15.27, 14.64, 14.61, 14.46, 14.25, 13.56, 12.99,
#        12.85, 12.37, 11.92, 11.53, 10.89, 10.41, 10.1 ,  9.52,  9.16,
#         8.36,  8.03,  7.49,  6.25,  5.62,  5.59,  6.17,  5.95,  5.75,
#         5.57,  5.54,  5.15,  5.37,  4.6 ,  4.01,  3.91,  3.84,  2.94,
#         2.84,  2.52,  2.26,  1.9 ,  2.14,  2.39,  2.31,  2.53,  2.71,
#         1.88,  1.32,  1.27,  1.14,  1.95,  0.93,  0.61,  0.34,  0.33,
#         0.17,  0.17,  0.75,  1.15,  1.19,  1.09,  0.63,  2.15,  2.85,
#         0.98,  0.93,  2.23,  1.99,  1.73,  0.76,  1.07,  2.71,  2.16,
#         2.34,  2.73,  3.1 ,  3.02,  2.55,  2.15,  1.58,  1.76,  5.  ,
#         3.9 ,  3.37,  2.72,  3.82,  3.26,  3.47,  4.01,  3.9 ,  3.68,
#         4.64,  5.23,  5.24,  5.25,  4.67,  4.71,  4.45,  4.85,  5.62,
#         5.88,  6.04,  6.58,  6.46,  6.41,  6.41,  6.63,  6.72,  7.02,
#         7.14,  6.89,  6.83,  7.28,  7.71,  7.43,  7.7 ,  8.14,  8.41,
#         8.88,  8.93,  8.84,  8.9 ,  9.1 ,  9.26,  9.56,  9.86,  9.85,
#         9.52,  9.71,  9.8 ,  9.98,  9.91, 10.01,  9.82,  9.99, 10.5 ,
#        10.3 , 10.85, 11.43, 11.55, 11.78, 11.82, 12.05, 11.88, 12.29,
#        12.63, 13.45, 13.9 , 14.42, 14.05, 14.84, 15.34, 15.53, 14.85,
#        14.58, 15.17, 15.03, 15.15, 15.78, 16.77, 17.55, 17.53, 17.77,
#        17.9 , 17.85, 17.81, 18.23, 19.53, 19.68, 19.31, 19.63, 19.26,
#        19.71, 20.54, 21.13, 20.29, 20.34, 20.25, 20.5 , 20.49, 21.01,
#        21.11, 21.46, 22.39, 22.38, 21.7 , 22.28, 22.84, 22.86, 22.2 ,
#        22.75, 22.34, 22.93, 23.49, 23.51, 24.68, 26.15, 26.35, 27.79,
#        28.21, 28.86, 28.18, 27.27, 27.59, 27.72, 28.47, 29.49, 28.63,
#        28.63, 28.9 , 29.63, 28.24, 27.48, 28.84, 30.29, 28.77, 27.65,
#        28.5 , 29.42, 29.47, 30.01, 29.94, 30.54, 31.07, 31.06, 31.68,
#        32.56, 33.7 , 35.19, 35.54, 35.76, 35.59, 36.19, 36.15, 36.74,
#        36.34, 37.16, 37.75, 38.1 , 38.13, 38.21, 38.3 , 38.27, 38.36,
#        38.66, 39.35, 39.02, 38.83, 39.17, 39.38, 39.33, 39.24, 39.93,
#        40.34, 39.92, 39.54, 39.3 , 40.12, 40.51, 40.17, 40.02, 40.25,
#        40.51, 40.44, 40.25, 40.64, 41.29, 41.28, 41.43, 41.72, 42.13,
#        41.89, 42.1 , 42.38, 42.26, 41.8 , 42.32, 41.25, 41.48, 40.57,
#        40.77, 41.5 , 42.13, 40.81, 40.02, 40.77, 41.68, 41.09, 40.56,
#        39.77, 39.28, 38.64, 40.21, 40.96, 42.13, 43.22, 45.26, 42.58,
#        50.79, 50.53, 51.  , 51.59, 58.61, 57.48, 60.21, 64.93, 63.07,
#        64.8 , 63.82, 62.39, 52.92, 54.92, 57.71, 60.16, 59.92, 56.59,
#        55.37]), array([57.99, 62.4 , 60.96, 62.83, 58.65, 56.01, 58.87, 65.26, 66.48,
#        64.57, 64.85, 65.22, 59.44, 60.91, 59.46, 57.86, 57.01, 60.85,
#        58.22, 51.76, 54.32, 58.36, 60.2 , 60.82, 59.63, 54.32, 51.97,
#        53.94, 54.99, 53.67, 52.23, 54.03, 55.36, 53.81, 53.58, 54.1 ,
#        51.49, 51.32, 49.86, 48.07, 49.41, 48.79, 50.2 , 50.61, 51.26,
#        49.97, 48.88, 47.45, 48.41, 48.31, 48.  , 46.61, 46.48, 46.4 ,
#        45.35, 46.02, 46.67, 48.03, 47.44, 46.89, 43.97, 45.48, 45.58,
#        44.62, 43.66, 43.76, 44.07, 43.51, 43.23, 41.92, 41.61, 41.67,
#        41.22, 40.33, 40.17, 40.04, 39.25, 38.17, 34.81, 36.14, 36.11,
#        35.59, 35.55, 35.67, 35.55, 35.23, 34.38, 33.3 , 32.73, 32.93,
#        33.05, 32.42, 32.14, 31.92, 31.68, 31.99, 32.3 , 32.3 , 32.12,
#        31.21, 30.72, 29.65, 29.21, 28.48, 27.42, 27.12, 27.12, 26.97,
#        26.77, 26.5 , 26.35, 26.  , 26.19, 26.08, 25.98, 25.54, 25.36,
#        25.69, 25.01, 24.17, 24.31, 24.17, 23.8 , 24.09, 24.17, 23.81,
#        23.66, 23.14, 21.73, 22.53, 22.63, 22.46, 22.02, 21.59, 21.5 ,
#        21.38, 20.19, 19.47, 19.32, 19.33, 19.91, 19.88, 19.36, 19.29,
#        19.25, 18.8 , 18.16, 17.86, 17.09, 17.06, 16.91, 16.9 , 16.78,
#        16.86, 16.78, 16.84, 16.25, 16.61, 16.27, 15.79, 16.  , 15.88,
#        15.34, 15.3 , 15.34, 14.9 , 14.64, 14.5 , 14.16, 14.04, 13.97,
#        14.1 , 14.3 , 13.64, 13.52, 13.27, 13.12, 12.8 , 12.44, 12.64,
#        12.92, 13.08, 13.01, 12.41, 12.26, 12.37, 12.58, 12.68, 12.44,
#        12.8 , 12.54, 12.37, 12.4 , 12.39, 12.09, 12.11, 12.68, 13.15,
#        13.23, 13.38, 13.84, 14.02, 14.16, 14.44, 14.23, 14.35, 14.61,
#        14.75, 15.06, 15.19, 15.36, 15.51, 15.57, 15.82, 15.84, 15.84,
#        15.65, 15.65, 15.75, 15.7 , 15.62, 15.69, 15.84, 15.79, 16.03,
#        16.27, 16.79, 16.95, 17.1 , 16.87, 16.83, 16.34, 16.33, 16.51,
#        16.41, 16.23, 15.95, 15.83, 15.68, 15.54, 15.27, 14.89, 14.8 ,
#        14.58, 14.47, 14.31, 14.09, 13.6 , 13.63, 13.87, 13.84, 13.58,
#        13.03, 13.09, 12.97, 12.73, 12.68, 12.47, 12.37, 11.93, 11.76,
#        11.57, 11.54, 11.28, 11.09, 11.27, 10.99, 10.65, 10.32,  9.94,
#         9.77,  9.59,  9.36,  9.28,  9.  ,  9.18,  9.09,  8.78,  8.69,
#         9.37,  9.17,  8.48,  8.46,  7.99,  7.68,  7.24,  6.92,  6.62,
#         6.29,  5.8 ,  5.26,  5.2 ,  5.11,  4.78,  4.43,  4.15,  3.45,
#         3.  ,  2.99,  2.75,  2.67,  2.87,  3.35,  3.72,  3.86,  3.83,
#         3.67,  3.86,  3.98,  4.07,  4.27,  4.67,  5.17,  5.15,  5.16,
#         5.72,  5.88,  6.64,  6.58,  6.35,  7.32,  8.1 ,  8.02,  8.03,
#         8.31,  8.01,  8.79,  9.8 ,  9.21,  9.9 , 10.73, 10.74, 10.32,
#        10.17, 11.13, 11.31, 10.72, 10.93, 10.19,  9.91,  9.63, 11.58,
#        12.52, 12.52, 11.26, 13.17, 11.83, 11.14, 11.05, 10.74, 11.77,
#        14.24, 13.16, 12.04, 13.98, 13.35, 14.05, 14.33, 14.23, 15.89,
#        15.33, 15.54, 15.63, 16.25, 17.12, 17.37, 17.75, 18.2 , 18.27,
#        18.09, 18.07, 17.98, 18.46, 18.67, 19.19, 19.96, 20.38, 20.98,
#        21.41, 21.53, 21.42, 21.26, 21.58, 21.86, 21.98, 21.69, 21.67,
#        21.89, 22.04, 22.37, 22.49, 22.4 , 22.18, 22.02, 22.11, 22.22,
#        22.27, 22.15, 21.7 , 21.44, 21.17, 20.89, 20.53, 20.43, 20.04,
#        20.15, 20.28, 20.01, 19.74, 19.7 , 19.78, 19.74, 19.4 , 19.41,
#        19.57, 19.4 , 19.29, 19.05, 18.87, 18.87, 18.47, 18.24, 18.34,
#        18.  , 17.48, 17.16, 16.42, 16.35, 15.91, 15.66, 15.44, 15.23,
#        14.89, 14.69, 14.4 , 14.39, 13.94, 13.77, 13.4 , 12.95, 12.54,
#        12.08, 11.97, 12.11, 11.9 , 11.86, 11.81, 11.83, 11.72, 11.52,
#        10.85, 10.7 , 10.93, 11.41, 10.66, 10.24, 10.12,  9.73,  9.29,
#         9.07,  9.03,  8.85,  8.44,  8.01,  7.51,  7.06,  6.68,  6.98,
#         7.06,  6.76,  7.04,  7.54,  7.52,  7.52,  7.75,  8.22,  8.44,
#         8.3 ,  8.24,  8.61, 10.14,  9.46, 10.62, 10.81, 10.18, 10.18,
#         9.95, 11.11, 12.51, 13.27, 13.52, 13.52, 12.68, 12.09, 12.82,
#        12.84, 12.88, 12.86, 13.05, 12.58, 11.78, 13.52, 13.24, 12.16,
#        11.98, 13.24, 11.95, 11.43, 11.68, 13.53, 13.58, 12.41, 13.06,
#        13.67, 14.83, 15.82, 16.04, 16.59, 16.68, 17.26, 16.3 , 16.85,
#        17.43, 17.77, 18.05, 18.62, 19.3 , 20.34, 20.3 , 20.96, 21.51,
#        21.27, 21.51, 22.22, 22.56, 22.94, 23.1 , 23.36, 23.85, 24.05,
#        24.44, 24.54, 24.79, 25.09, 25.52, 25.99, 26.17, 26.4 , 26.29,
#        26.44, 27.02, 27.5 , 27.59, 28.03, 28.38, 28.65, 29.13, 29.3 ,
#        29.51, 29.61, 29.43, 29.57, 29.47, 29.64, 29.82, 29.86, 30.11,
#        30.36, 30.55, 30.66, 30.98, 31.39, 31.75, 32.04, 32.26, 32.3 ,
#        32.41, 32.63, 32.95, 33.37, 33.69, 34.13, 34.04, 33.87, 33.94,
#        33.86, 34.08, 34.51, 34.8 , 34.95, 35.13, 35.28, 35.35, 35.34,
#        35.76, 36.33, 36.4 , 36.8 , 37.23, 37.24, 37.15, 37.17, 37.09,
#        37.17, 37.45, 37.84, 38.45, 38.76, 38.78, 38.89, 39.04, 39.19,
#        39.11, 38.56, 38.41, 38.71, 39.05, 39.35, 39.35, 39.52, 39.44,
#        39.51, 39.89, 40.24, 40.29, 40.15, 40.72, 41.43, 41.54, 41.62,
#        41.77, 41.92, 41.98, 42.14, 42.46, 42.7 , 43.48, 44.04, 43.72,
#        43.8 , 43.55, 43.47, 43.62, 43.89, 43.78, 44.35, 44.65, 44.58,
#        44.62, 44.31, 44.07, 43.84, 43.78, 44.04, 43.92, 44.63, 44.99,
#        45.64, 45.75, 45.56, 45.44, 45.45, 45.75, 45.77, 45.87, 46.2 ,
#        46.79, 47.  , 46.78, 46.97, 47.  , 47.05, 47.21, 46.87, 46.74,
#        46.84, 46.66, 45.97, 45.98, 47.66, 48.14, 48.67, 49.76, 50.81,
#        51.31, 51.81, 52.73, 53.37, 53.29, 53.68, 54.23, 54.63, 54.74,
#        55.27, 55.58, 55.79, 55.94, 56.02, 56.53, 56.72, 57.05, 57.43,
#        57.21, 57.14, 58.52, 58.46, 57.18, 59.8 , 60.93, 60.01, 59.84,
#        59.9 , 60.43, 61.03, 62.22, 61.19, 61.  , 61.09, 64.33, 64.55,
#        67.61, 66.18, 66.  , 68.97, 69.8 , 70.08, 71.7 , 72.47, 73.12,
#        72.51, 70.65, 68.59, 68.3 , 70.25, 69.27, 68.45, 68.24, 68.62])], [array([58.96, 56.61, 55.05, 56.9 , 57.34, 52.84, 54.75, 56.83, 61.56,
#        64.06, 64.56, 68.78, 69.03, 64.33, 62.41, 55.17, 53.2 , 50.98,
#        49.96, 49.05, 50.63, 49.54, 48.1 , 49.77, 53.35, 50.12, 44.44,
#        41.87, 43.5 , 45.64, 45.74, 45.19, 44.  , 43.14, 42.56, 43.9 ,
#        41.94, 42.33, 43.97, 46.23, 47.47, 47.43, 46.63, 47.78, 45.75,
#        48.49, 48.25, 47.75, 48.38, 47.17, 45.61, 44.57, 44.8 , 45.27,
#        46.63, 48.72, 47.97, 47.62, 47.22, 47.43, 47.28, 46.25, 46.3 ,
#        46.18, 46.77, 47.46, 47.09, 47.01, 47.64, 47.08, 46.7 , 45.79,
#        45.45, 45.51, 45.32, 46.1 , 46.71, 45.86, 44.67, 43.73, 44.16,
#        43.71, 46.69, 46.19, 47.39, 47.8 , 47.47, 47.36, 47.84, 48.36,
#        48.61, 48.28, 48.07, 48.52, 48.56, 48.46, 47.92, 47.45, 48.15,
#        47.9 , 46.58, 45.68, 44.98, 45.23, 44.7 , 45.22, 45.35, 44.97,
#        45.21, 45.11, 45.34, 45.15, 45.53, 46.35, 46.95, 46.96, 46.99,
#        47.11, 46.25, 45.9 , 45.76, 44.8 , 44.65, 44.73, 44.53, 43.27,
#        42.54, 42.97, 42.63, 41.75, 41.28, 41.64, 41.54, 41.07, 40.93,
#        41.12, 41.12, 40.98, 41.13, 41.03, 40.3 , 40.55, 40.75, 41.08,
#        41.26, 41.14, 41.27, 40.58, 39.74, 38.49, 38.29, 36.77, 36.45,
#        36.22, 35.82, 34.8 , 34.45, 34.35, 34.28, 33.4 , 33.18, 32.91,
#        33.09, 32.52, 32.53, 32.56, 32.17, 32.06, 32.17, 32.6 , 32.03,
#        31.89, 31.42, 31.26, 30.96, 31.12, 30.5 , 31.08, 30.89, 30.92,
#        30.72, 30.02, 29.64, 28.32, 27.38, 26.93, 26.11, 25.71, 25.69,
#        25.94, 25.57, 24.95, 25.17, 25.9 , 25.06, 25.62, 25.47, 26.39,
#        25.79, 25.75, 25.74, 24.86, 24.44, 24.36, 24.42, 24.48, 24.4 ,
#        24.08, 23.63, 23.28, 22.59, 21.79, 21.2 , 21.01, 20.85, 20.71,
#        19.62, 18.55, 17.87, 17.58, 17.41, 17.3 , 16.63, 16.86, 16.63,
#        16.05, 16.38, 16.3 , 16.13, 15.89, 15.63, 15.6 , 15.44, 15.15,
#        14.89, 14.73, 14.51, 13.77, 13.17, 13.04, 12.68, 12.03, 11.92,
#        11.64, 11.66, 11.07, 10.92, 11.13, 10.93, 10.85, 10.63, 10.51,
#        10.03,  9.59,  9.39,  9.46,  9.23,  9.67,  9.64,  9.57,  9.39,
#         9.35,  9.21,  8.94,  8.27,  7.84,  7.44,  7.3 ,  7.03,  6.91,
#         6.71,  6.88,  6.8 ,  6.47,  6.26,  6.19,  5.99,  5.98,  5.85,
#         5.98,  5.99,  6.08,  5.81,  5.29,  4.84,  4.41,  4.51,  4.4 ,
#         4.15,  4.11,  4.62,  3.76,  3.66,  4.36,  4.64,  4.46,  4.08,
#         3.97,  3.87,  2.85,  2.46,  3.56,  3.72,  3.26,  2.64,  2.63,
#         2.34,  2.55,  2.81,  2.38,  2.27,  2.17,  2.29,  2.31,  2.51,
#         2.83,  2.8 ,  2.91,  2.83,  2.8 ,  2.92,  3.07,  3.17,  3.35,
#         3.78,  4.77,  4.76,  4.62,  4.92,  5.08,  4.85,  4.87,  5.34,
#         5.72,  5.58,  5.5 ,  5.34,  5.63,  5.3 ,  5.44,  5.6 ,  5.68,
#         5.55,  6.23,  6.76,  6.84,  7.41,  7.53,  8.35,  8.13,  8.41,
#         9.76,  9.83,  7.97,  8.03,  9.52,  9.7 ,  9.53,  8.99,  9.11,
#        11.19, 11.47, 11.86, 12.81, 12.68, 12.78, 13.02, 13.49, 13.46,
#        13.74, 13.91, 13.67, 13.71, 13.65, 13.42, 13.49, 13.76, 13.47,
#        13.43, 13.65, 13.7 , 13.65, 13.45, 14.14, 14.4 , 13.89, 14.41,
#        14.39, 14.26, 14.21, 14.49, 14.65, 14.88, 15.01, 15.4 , 16.05,
#        16.13, 16.15, 16.53, 16.66, 16.8 , 17.03, 17.45, 18.27, 18.54,
#        18.62, 19.08, 19.5 , 19.71, 20.77, 21.19, 21.4 , 21.93, 22.89,
#        23.59, 23.57, 23.7 , 24.45, 25.  , 25.62, 25.61, 26.26, 27.13,
#        28.43, 28.16, 28.52, 28.18, 28.36, 29.63, 29.23, 29.49, 32.47,
#        33.24, 33.13, 32.99, 33.34, 33.88, 34.67, 34.72, 34.66, 35.81,
#        36.55, 35.97, 36.44, 37.16, 38.19, 37.91, 38.38, 38.71, 39.37,
#        39.69, 40.91, 40.85, 41.13, 41.27, 41.07, 41.29, 41.56, 41.53,
#        41.69, 41.77, 41.86, 42.32, 42.76, 43.27, 43.28, 43.08, 43.04,
#        42.94, 42.8 , 43.1 , 42.8 , 42.53, 42.7 , 42.88, 43.32, 42.96,
#        43.16, 43.4 , 43.04, 43.03, 43.77, 44.06, 43.87, 44.11, 43.68,
#        41.98, 42.18, 42.2 , 42.19, 42.01, 41.84, 42.79, 42.27, 42.38,
#        42.39, 42.07, 41.53, 41.48, 41.38, 41.41, 41.83, 41.96, 41.82,
#        41.63, 41.5 , 41.47, 41.49, 41.65, 41.55, 41.96, 42.23, 42.44,
#        42.97, 43.18, 43.21, 43.36, 43.19, 43.17, 43.33, 43.6 , 43.26,
#        43.67, 43.53, 43.9 , 44.56, 44.61, 44.6 , 44.05, 44.25, 44.79,
#        45.49, 45.28, 46.1 , 46.56, 46.17, 46.68, 45.86, 46.07, 46.17,
#        46.13, 47.01, 48.65, 47.18, 46.81, 46.85, 46.85, 46.28, 47.24,
#        47.4 , 46.38, 47.7 , 50.08, 49.97, 47.77, 47.64, 50.35, 49.31,
#        49.06, 51.59, 53.82, 54.18, 53.24, 52.44, 54.1 , 54.74, 54.59,
#        55.16, 54.38, 55.58, 55.4 , 55.38, 55.92, 56.5 , 56.89, 56.15,
#        57.11, 60.27, 61.45, 57.84, 59.92, 65.22, 67.78, 67.07, 62.79,
#        64.1 , 63.43, 63.27, 63.06, 61.96, 61.69, 60.54]), array([67.77, 69.79, 69.35, 70.66, 66.77, 62.15, 66.48, 70.05, 71.17,
#        73.84, 63.46, 63.38, 62.29, 60.17, 61.4 , 58.06, 55.12, 52.07,
#        53.84, 56.24, 55.93, 53.45, 54.18, 51.2 , 46.38, 49.82, 48.92,
#        47.77, 48.08, 48.43, 50.57, 45.21, 45.91, 45.25, 45.19, 49.23,
#        41.13, 39.63, 38.18, 39.94, 40.25, 40.07, 39.82, 39.9 , 39.29,
#        39.22, 38.75, 40.47, 38.81, 39.45, 42.13, 44.58, 43.91, 43.73,
#        42.52, 42.06, 42.53, 43.39, 43.43, 42.84, 42.62, 43.15, 43.27,
#        43.49, 43.13, 42.78, 42.79, 43.13, 42.56, 42.53, 43.01, 43.77,
#        44.19, 44.21, 43.84, 42.59, 42.54, 42.56, 42.  , 41.13, 40.75,
#        42.44, 44.88, 45.39, 42.6 , 41.21, 42.86, 44.13, 43.46, 43.19,
#        43.46, 42.57, 43.48, 43.27, 43.27, 41.88, 41.93, 42.55, 40.49,
#        40.52, 41.66, 41.49, 41.47, 40.49, 41.05, 41.31, 40.  , 39.22,
#        38.21, 37.98, 37.82, 36.46, 35.54, 35.08, 35.02, 35.09, 35.13,
#        34.91, 34.08, 34.26, 33.82, 32.95, 32.23, 30.47, 31.59, 32.05,
#        31.5 , 31.64, 33.54, 33.66, 32.65, 33.33, 33.13, 32.31, 32.28,
#        32.1 , 30.96, 30.52, 31.5 , 30.81, 29.91, 28.72, 27.75, 26.53,
#        27.24, 27.37, 26.92, 27.2 , 26.46, 25.97, 25.66, 24.87, 24.43,
#        22.88, 22.6 , 22.55, 22.04, 21.13, 20.8 , 20.49, 19.93, 19.11,
#        18.52, 17.93, 17.34, 17.36, 17.24, 16.89, 16.76, 16.84, 17.06,
#        17.07, 16.6 , 16.41, 15.87, 14.49, 14.66, 14.7 , 15.07, 14.41,
#        14.26, 14.51, 14.96, 15.  , 14.96, 14.82, 14.59, 14.23, 13.25,
#        12.86, 11.97, 11.65, 11.33, 10.82, 10.49, 10.4 , 10.01,  9.79,
#        10.02,  9.75,  9.19,  9.02,  8.63,  8.27,  7.92,  7.58,  7.48,
#         7.5 ,  6.91,  6.31,  5.92,  5.92,  6.06,  5.7 ,  5.11,  4.92,
#         5.2 ,  4.6 ,  4.22,  3.91,  4.29,  4.39,  4.01,  3.47,  3.01,
#         2.69,  2.41,  2.32,  2.54,  3.06,  2.83,  2.36,  2.26,  2.52,
#         2.09,  2.26,  2.36,  2.68,  1.92,  2.11,  2.28,  2.17,  1.66,
#         2.13,  1.23,  0.38,  1.  ,  1.34,  2.22,  2.33,  3.59,  2.29,
#         2.28,  1.74,  1.52,  2.25,  2.72,  2.72,  2.68,  3.09,  2.92,
#         2.53,  2.57,  2.98,  2.88,  3.31,  3.41,  3.76,  3.77,  3.91,
#         3.87,  3.67,  3.43,  3.55,  3.8 ,  3.9 ,  3.63,  4.15,  4.47,
#         4.71,  4.76,  4.96,  4.92,  5.25,  5.47,  5.75,  6.3 ,  6.73,
#         7.19,  7.1 ,  7.35,  7.57,  7.53,  7.63,  7.9 ,  7.86,  7.97,
#         8.12,  8.42,  8.36,  9.39,  9.75,  9.86, 10.16, 10.52, 10.74,
#        10.83, 10.92, 10.94, 10.76, 10.86, 10.98, 11.37, 12.04, 12.38,
#        12.98, 14.11, 14.24, 14.15, 15.23, 16.45, 16.28, 16.58, 16.64,
#        17.55, 18.34, 18.82, 18.95, 19.84, 21.21, 21.39, 21.61, 21.98,
#        21.65, 21.77, 21.97, 21.96, 22.28, 22.41, 22.4 , 22.92, 22.98,
#        23.56, 23.87, 23.31, 23.07, 22.68, 24.4 , 23.94, 24.16, 25.35,
#        24.93, 24.37, 25.21, 25.29, 25.62, 25.64, 26.47, 26.96, 27.97,
#        28.29, 28.11, 27.77, 27.65, 28.34, 28.78, 28.79, 29.69, 30.4 ,
#        30.  , 30.27, 30.72, 31.23, 31.24, 31.25, 32.11, 32.37, 32.99,
#        33.24, 33.84, 34.88, 35.61, 36.56, 37.19, 37.39, 38.99, 38.88,
#        40.08, 40.92, 40.61, 40.52, 40.36, 40.76, 41.06, 41.76, 41.79,
#        41.54, 41.63, 41.75, 41.26, 40.93, 40.84, 40.36, 40.54, 40.98,
#        41.37, 41.02, 41.11, 41.52, 41.77, 41.68, 41.66, 42.22, 42.92,
#        43.25, 43.37, 43.37, 43.71, 43.92, 43.83, 43.93, 44.29, 44.49,
#        44.5 , 44.88, 44.8 , 44.81, 45.08, 45.19, 45.58, 45.86, 46.43,
#        47.03, 46.7 , 46.57, 46.88, 47.14, 47.13, 47.09, 47.38, 47.19,
#        47.39, 47.21, 47.12, 47.39, 47.15, 47.46, 47.27, 47.29, 47.48,
#        47.33, 47.67, 47.5 , 47.24, 47.21, 47.15, 46.76, 46.76, 46.61,
#        46.42, 47.13, 48.09, 48.69, 49.54, 49.95, 49.43, 51.12, 52.9 ,
#        52.96, 51.88, 52.08, 55.12, 54.49, 53.95, 55.64, 55.59, 55.48,
#        55.52, 54.88, 55.89, 55.65, 56.88, 56.28, 57.14, 55.32, 58.36,
#        60.4 , 60.14, 60.02, 59.91, 60.21, 59.94, 61.59, 61.54, 61.57,
#        60.24, 61.09, 62.95, 58.71, 58.51, 59.76, 60.55, 62.12, 61.46,
#        62.34, 61.86, 61.35, 61.41, 61.98, 62.62, 62.55, 61.9 , 63.38,
#        63.78, 62.38, 62.72, 64.16, 64.06, 65.  , 65.71, 64.28, 64.69,
#        64.38, 64.07, 63.57, 64.66]), array([65.24, 66.02, 66.38, 66.59, 66.39, 67.06, 68.13, 68.74, 69.24,
#        69.19, 68.28, 68.65, 68.31, 68.55, 68.45, 67.77, 66.88, 65.56,
#        64.91, 63.74, 60.13, 59.03, 60.8 , 60.75, 61.97, 63.81, 63.55,
#        60.86, 59.99, 58.05, 58.9 , 59.6 , 58.16, 58.15, 56.63, 53.71,
#        54.56, 54.22, 55.42, 55.83, 55.61, 55.  , 55.05, 54.6 , 54.76,
#        55.03, 55.31, 55.39, 55.94, 56.07, 56.22, 54.9 , 54.98, 55.1 ,
#        55.03, 54.24, 53.7 , 53.16, 52.39, 52.27, 52.24, 51.36, 50.76,
#        50.35, 50.48, 49.57, 49.39, 49.01, 48.02, 46.91, 46.5 , 46.11,
#        46.25, 45.55, 45.14, 46.97, 47.19, 45.84, 44.63, 44.82, 45.01,
#        45.19, 45.1 , 44.54, 43.6 , 42.54, 42.1 , 41.72, 41.43, 41.26,
#        40.71, 40.1 , 39.04, 38.83, 39.  , 38.82, 39.12, 38.93, 38.04,
#        38.3 , 37.86, 36.89, 37.03, 35.79, 35.5 , 34.96, 34.85, 34.53,
#        34.39, 34.11, 34.42, 34.02, 33.45, 33.27, 33.16, 33.02, 33.44,
#        33.27, 33.05, 33.49, 33.48, 33.37, 33.32, 33.33, 33.26, 32.9 ,
#        32.43, 31.95, 31.69, 31.56, 31.12, 30.51, 30.03, 29.69, 29.95,
#        29.76, 29.47, 28.9 , 28.98, 28.87, 28.62, 28.4 , 28.3 , 28.05,
#        28.  , 28.5 , 27.65, 27.01, 26.51, 26.89, 25.74, 24.7 , 25.15,
#        25.15, 24.86, 24.73, 24.96, 25.29, 24.94, 24.88, 24.93, 24.23,
#        23.98, 23.93, 23.81, 23.53, 23.46, 22.84, 22.83, 22.4 , 22.29,
#        21.75, 21.69, 21.36, 21.16, 20.82, 20.28, 19.67, 19.49, 19.18,
#        18.94, 18.81, 18.7 , 18.18, 18.15, 18.  , 17.99, 17.73, 17.29,
#        16.44, 16.  , 15.27, 14.64, 14.61, 14.46, 14.25, 13.56, 12.99,
#        12.85, 12.37, 11.92, 11.53, 10.89, 10.41, 10.1 ,  9.52,  9.16,
#         8.36,  8.03,  7.49,  6.25,  5.62,  5.59,  6.17,  5.95,  5.75,
#         5.57,  5.54,  5.15,  5.37,  4.6 ,  4.01,  3.91,  3.84,  2.94,
#         2.84,  2.52,  2.26,  1.9 ,  2.14,  2.39,  2.31,  2.53,  2.71,
#         1.88,  1.32,  1.27,  1.14,  1.95,  0.93,  0.61,  0.34,  0.33,
#         0.17,  0.17,  0.75,  1.15,  1.19,  1.09,  0.63,  2.15,  2.85,
#         0.98,  0.93,  2.23,  1.99,  1.73,  0.76,  1.07,  2.71,  2.16,
#         2.34,  2.73,  3.1 ,  3.02,  2.55,  2.15,  1.58,  1.76,  5.  ,
#         3.9 ,  3.37,  2.72,  3.82,  3.26,  3.47,  4.01,  3.9 ,  3.68,
#         4.64,  5.23,  5.24,  5.25,  4.67,  4.71,  4.45,  4.85,  5.62,
#         5.88,  6.04,  6.58,  6.46,  6.41,  6.41,  6.63,  6.72,  7.02,
#         7.14,  6.89,  6.83,  7.28,  7.71,  7.43,  7.7 ,  8.14,  8.41,
#         8.88,  8.93,  8.84,  8.9 ,  9.1 ,  9.26,  9.56,  9.86,  9.85,
#         9.52,  9.71,  9.8 ,  9.98,  9.91, 10.01,  9.82,  9.99, 10.5 ,
#        10.3 , 10.85, 11.43, 11.55, 11.78, 11.82, 12.05, 11.88, 12.29,
#        12.63, 13.45, 13.9 , 14.42, 14.05, 14.84, 15.34, 15.53, 14.85,
#        14.58, 15.17, 15.03, 15.15, 15.78, 16.77, 17.55, 17.53, 17.77,
#        17.9 , 17.85, 17.81, 18.23, 19.53, 19.68, 19.31, 19.63, 19.26,
#        19.71, 20.54, 21.13, 20.29, 20.34, 20.25, 20.5 , 20.49, 21.01,
#        21.11, 21.46, 22.39, 22.38, 21.7 , 22.28, 22.84, 22.86, 22.2 ,
#        22.75, 22.34, 22.93, 23.49, 23.51, 24.68, 26.15, 26.35, 27.79,
#        28.21, 28.86, 28.18, 27.27, 27.59, 27.72, 28.47, 29.49, 28.63,
#        28.63, 28.9 , 29.63, 28.24, 27.48, 28.84, 30.29, 28.77, 27.65,
#        28.5 , 29.42, 29.47, 30.01, 29.94, 30.54, 31.07, 31.06, 31.68,
#        32.56, 33.7 , 35.19, 35.54, 35.76, 35.59, 36.19, 36.15, 36.74,
#        36.34, 37.16, 37.75, 38.1 , 38.13, 38.21, 38.3 , 38.27, 38.36,
#        38.66, 39.35, 39.02, 38.83, 39.17, 39.38, 39.33, 39.24, 39.93,
#        40.34, 39.92, 39.54, 39.3 , 40.12, 40.51, 40.17, 40.02, 40.25,
#        40.51, 40.44, 40.25, 40.64, 41.29, 41.28, 41.43, 41.72, 42.13,
#        41.89, 42.1 , 42.38, 42.26, 41.8 , 42.32, 41.25, 41.48, 40.57,
#        40.77, 41.5 , 42.13, 40.81, 40.02, 40.77, 41.68, 41.09, 40.56,
#        39.77, 39.28, 38.64, 40.21, 40.96, 42.13, 43.22, 45.26, 42.58,
#        50.79, 50.53, 51.  , 51.59, 58.61, 57.48, 60.21, 64.93, 63.07,
#        64.8 , 63.82, 62.39, 52.92, 54.92, 57.71, 60.16, 59.92, 56.59,
#        55.37]), array([57.99, 62.4 , 60.96, 62.83, 58.65, 56.01, 58.87, 65.26, 66.48,
#        64.57, 64.85, 65.22, 59.44, 60.91, 59.46, 57.86, 57.01, 60.85,
#        58.22, 51.76, 54.32, 58.36, 60.2 , 60.82, 59.63, 54.32, 51.97,
#        53.94, 54.99, 53.67, 52.23, 54.03, 55.36, 53.81, 53.58, 54.1 ,
#        51.49, 51.32, 49.86, 48.07, 49.41, 48.79, 50.2 , 50.61, 51.26,
#        49.97, 48.88, 47.45, 48.41, 48.31, 48.  , 46.61, 46.48, 46.4 ,
#        45.35, 46.02, 46.67, 48.03, 47.44, 46.89, 43.97, 45.48, 45.58,
#        44.62, 43.66, 43.76, 44.07, 43.51, 43.23, 41.92, 41.61, 41.67,
#        41.22, 40.33, 40.17, 40.04, 39.25, 38.17, 34.81, 36.14, 36.11,
#        35.59, 35.55, 35.67, 35.55, 35.23, 34.38, 33.3 , 32.73, 32.93,
#        33.05, 32.42, 32.14, 31.92, 31.68, 31.99, 32.3 , 32.3 , 32.12,
#        31.21, 30.72, 29.65, 29.21, 28.48, 27.42, 27.12, 27.12, 26.97,
#        26.77, 26.5 , 26.35, 26.  , 26.19, 26.08, 25.98, 25.54, 25.36,
#        25.69, 25.01, 24.17, 24.31, 24.17, 23.8 , 24.09, 24.17, 23.81,
#        23.66, 23.14, 21.73, 22.53, 22.63, 22.46, 22.02, 21.59, 21.5 ,
#        21.38, 20.19, 19.47, 19.32, 19.33, 19.91, 19.88, 19.36, 19.29,
#        19.25, 18.8 , 18.16, 17.86, 17.09, 17.06, 16.91, 16.9 , 16.78,
#        16.86, 16.78, 16.84, 16.25, 16.61, 16.27, 15.79, 16.  , 15.88,
#        15.34, 15.3 , 15.34, 14.9 , 14.64, 14.5 , 14.16, 14.04, 13.97,
#        14.1 , 14.3 , 13.64, 13.52, 13.27, 13.12, 12.8 , 12.44, 12.64,
#        12.92, 13.08, 13.01, 12.41, 12.26, 12.37, 12.58, 12.68, 12.44,
#        12.8 , 12.54, 12.37, 12.4 , 12.39, 12.09, 12.11, 12.68, 13.15,
#        13.23, 13.38, 13.84, 14.02, 14.16, 14.44, 14.23, 14.35, 14.61,
#        14.75, 15.06, 15.19, 15.36, 15.51, 15.57, 15.82, 15.84, 15.84,
#        15.65, 15.65, 15.75, 15.7 , 15.62, 15.69, 15.84, 15.79, 16.03,
#        16.27, 16.79, 16.95, 17.1 , 16.87, 16.83, 16.34, 16.33, 16.51,
#        16.41, 16.23, 15.95, 15.83, 15.68, 15.54, 15.27, 14.89, 14.8 ,
#        14.58, 14.47, 14.31, 14.09, 13.6 , 13.63, 13.87, 13.84, 13.58,
#        13.03, 13.09, 12.97, 12.73, 12.68, 12.47, 12.37, 11.93, 11.76,
#        11.57, 11.54, 11.28, 11.09, 11.27, 10.99, 10.65, 10.32,  9.94,
#         9.77,  9.59,  9.36,  9.28,  9.  ,  9.18,  9.09,  8.78,  8.69,
#         9.37,  9.17,  8.48,  8.46,  7.99,  7.68,  7.24,  6.92,  6.62,
#         6.29,  5.8 ,  5.26,  5.2 ,  5.11,  4.78,  4.43,  4.15,  3.45,
#         3.  ,  2.99,  2.75,  2.67,  2.87,  3.35,  3.72,  3.86,  3.83,
#         3.67,  3.86,  3.98,  4.07,  4.27,  4.67,  5.17,  5.15,  5.16,
#         5.72,  5.88,  6.64,  6.58,  6.35,  7.32,  8.1 ,  8.02,  8.03,
#         8.31,  8.01,  8.79,  9.8 ,  9.21,  9.9 , 10.73, 10.74, 10.32,
#        10.17, 11.13, 11.31, 10.72, 10.93, 10.19,  9.91,  9.63, 11.58,
#        12.52, 12.52, 11.26, 13.17, 11.83, 11.14, 11.05, 10.74, 11.77,
#        14.24, 13.16, 12.04, 13.98, 13.35, 14.05, 14.33, 14.23, 15.89,
#        15.33, 15.54, 15.63, 16.25, 17.12, 17.37, 17.75, 18.2 , 18.27,
#        18.09, 18.07, 17.98, 18.46, 18.67, 19.19, 19.96, 20.38, 20.98,
#        21.41, 21.53, 21.42, 21.26, 21.58, 21.86, 21.98, 21.69, 21.67,
#        21.89, 22.04, 22.37, 22.49, 22.4 , 22.18, 22.02, 22.11, 22.22,
#        22.27, 22.15, 21.7 , 21.44, 21.17, 20.89, 20.53, 20.43, 20.04,
#        20.15, 20.28, 20.01, 19.74, 19.7 , 19.78, 19.74, 19.4 , 19.41,
#        19.57, 19.4 , 19.29, 19.05, 18.87, 18.87, 18.47, 18.24, 18.34,
#        18.  , 17.48, 17.16, 16.42, 16.35, 15.91, 15.66, 15.44, 15.23,
#        14.89, 14.69, 14.4 , 14.39, 13.94, 13.77, 13.4 , 12.95, 12.54,
#        12.08, 11.97, 12.11, 11.9 , 11.86, 11.81, 11.83, 11.72, 11.52,
#        10.85, 10.7 , 10.93, 11.41, 10.66, 10.24, 10.12,  9.73,  9.29,
#         9.07,  9.03,  8.85,  8.44,  8.01,  7.51,  7.06,  6.68,  6.98,
#         7.06,  6.76,  7.04,  7.54,  7.52,  7.52,  7.75,  8.22,  8.44,
#         8.3 ,  8.24,  8.61, 10.14,  9.46, 10.62, 10.81, 10.18, 10.18,
#         9.95, 11.11, 12.51, 13.27, 13.52, 13.52, 12.68, 12.09, 12.82,
#        12.84, 12.88, 12.86, 13.05, 12.58, 11.78, 13.52, 13.24, 12.16,
#        11.98, 13.24, 11.95, 11.43, 11.68, 13.53, 13.58, 12.41, 13.06,
#        13.67, 14.83, 15.82, 16.04, 16.59, 16.68, 17.26, 16.3 , 16.85,
#        17.43, 17.77, 18.05, 18.62, 19.3 , 20.34, 20.3 , 20.96, 21.51,
#        21.27, 21.51, 22.22, 22.56, 22.94, 23.1 , 23.36, 23.85, 24.05,
#        24.44, 24.54, 24.79, 25.09, 25.52, 25.99, 26.17, 26.4 , 26.29,
#        26.44, 27.02, 27.5 , 27.59, 28.03, 28.38, 28.65, 29.13, 29.3 ,
#        29.51, 29.61, 29.43, 29.57, 29.47, 29.64, 29.82, 29.86, 30.11,
#        30.36, 30.55, 30.66, 30.98, 31.39, 31.75, 32.04, 32.26, 32.3 ,
#        32.41, 32.63, 32.95, 33.37, 33.69, 34.13, 34.04, 33.87, 33.94,
#        33.86, 34.08, 34.51, 34.8 , 34.95, 35.13, 35.28, 35.35, 35.34,
#        35.76, 36.33, 36.4 , 36.8 , 37.23, 37.24, 37.15, 37.17, 37.09,
#        37.17, 37.45, 37.84, 38.45, 38.76, 38.78, 38.89, 39.04, 39.19,
#        39.11, 38.56, 38.41, 38.71, 39.05, 39.35, 39.35, 39.52, 39.44,
#        39.51, 39.89, 40.24, 40.29, 40.15, 40.72, 41.43, 41.54, 41.62,
#        41.77, 41.92, 41.98, 42.14, 42.46, 42.7 , 43.48, 44.04, 43.72,
#        43.8 , 43.55, 43.47, 43.62, 43.89, 43.78, 44.35, 44.65, 44.58,
#        44.62, 44.31, 44.07, 43.84, 43.78, 44.04, 43.92, 44.63, 44.99,
#        45.64, 45.75, 45.56, 45.44, 45.45, 45.75, 45.77, 45.87, 46.2 ,
#        46.79, 47.  , 46.78, 46.97, 47.  , 47.05, 47.21, 46.87, 46.74,
#        46.84, 46.66, 45.97, 45.98, 47.66, 48.14, 48.67, 49.76, 50.81,
#        51.31, 51.81, 52.73, 53.37, 53.29, 53.68, 54.23, 54.63, 54.74,
#        55.27, 55.58, 55.79, 55.94, 56.02, 56.53, 56.72, 57.05, 57.43,
#        57.21, 57.14, 58.52, 58.46, 57.18, 59.8 , 60.93, 60.01, 59.84,
#        59.9 , 60.43, 61.03, 62.22, 61.19, 61.  , 61.09, 64.33, 64.55,
#        67.61, 66.18, 66.  , 68.97, 69.8 , 70.08, 71.7 , 72.47, 73.12,
#        72.51, 70.65, 68.59, 68.3 , 70.25, 69.27, 68.45, 68.24, 68.62])], [array([58.96, 56.61, 55.05, 56.9 , 57.34, 52.84, 54.75, 56.83, 61.56,
#        64.06, 64.56, 68.78, 69.03, 64.33, 62.41, 55.17, 53.2 , 50.98,
#        49.96, 49.05, 50.63, 49.54, 48.1 , 49.77, 53.35, 50.12, 44.44,
#        41.87, 43.5 , 45.64, 45.74, 45.19, 44.  , 43.14, 42.56, 43.9 ,
#        41.94, 42.33, 43.97, 46.23, 47.47, 47.43, 46.63, 47.78, 45.75,
#        48.49, 48.25, 47.75, 48.38, 47.17, 45.61, 44.57, 44.8 , 45.27,
#        46.63, 48.72, 47.97, 47.62, 47.22, 47.43, 47.28, 46.25, 46.3 ,
#        46.18, 46.77, 47.46, 47.09, 47.01, 47.64, 47.08, 46.7 , 45.79,
#        45.45, 45.51, 45.32, 46.1 , 46.71, 45.86, 44.67, 43.73, 44.16,
#        43.71, 46.69, 46.19, 47.39, 47.8 , 47.47, 47.36, 47.84, 48.36,
#        48.61, 48.28, 48.07, 48.52, 48.56, 48.46, 47.92, 47.45, 48.15,
#        47.9 , 46.58, 45.68, 44.98, 45.23, 44.7 , 45.22, 45.35, 44.97,
#        45.21, 45.11, 45.34, 45.15, 45.53, 46.35, 46.95, 46.96, 46.99,
#        47.11, 46.25, 45.9 , 45.76, 44.8 , 44.65, 44.73, 44.53, 43.27,
#        42.54, 42.97, 42.63, 41.75, 41.28, 41.64, 41.54, 41.07, 40.93,
#        41.12, 41.12, 40.98, 41.13, 41.03, 40.3 , 40.55, 40.75, 41.08,
#        41.26, 41.14, 41.27, 40.58, 39.74, 38.49, 38.29, 36.77, 36.45,
#        36.22, 35.82, 34.8 , 34.45, 34.35, 34.28, 33.4 , 33.18, 32.91,
#        33.09, 32.52, 32.53, 32.56, 32.17, 32.06, 32.17, 32.6 , 32.03,
#        31.89, 31.42, 31.26, 30.96, 31.12, 30.5 , 31.08, 30.89, 30.92,
#        30.72, 30.02, 29.64, 28.32, 27.38, 26.93, 26.11, 25.71, 25.69,
#        25.94, 25.57, 24.95, 25.17, 25.9 , 25.06, 25.62, 25.47, 26.39,
#        25.79, 25.75, 25.74, 24.86, 24.44, 24.36, 24.42, 24.48, 24.4 ,
#        24.08, 23.63, 23.28, 22.59, 21.79, 21.2 , 21.01, 20.85, 20.71,
#        19.62, 18.55, 17.87, 17.58, 17.41, 17.3 , 16.63, 16.86, 16.63,
#        16.05, 16.38, 16.3 , 16.13, 15.89, 15.63, 15.6 , 15.44, 15.15,
#        14.89, 14.73, 14.51, 13.77, 13.17, 13.04, 12.68, 12.03, 11.92,
#        11.64, 11.66, 11.07, 10.92, 11.13, 10.93, 10.85, 10.63, 10.51,
#        10.03,  9.59,  9.39,  9.46,  9.23,  9.67,  9.64,  9.57,  9.39,
#         9.35,  9.21,  8.94,  8.27,  7.84,  7.44,  7.3 ,  7.03,  6.91,
#         6.71,  6.88,  6.8 ,  6.47,  6.26,  6.19,  5.99,  5.98,  5.85,
#         5.98,  5.99,  6.08,  5.81,  5.29,  4.84,  4.41,  4.51,  4.4 ,
#         4.15,  4.11,  4.62,  3.76,  3.66,  4.36,  4.64,  4.46,  4.08,
#         3.97,  3.87,  2.85,  2.46,  3.56,  3.72,  3.26,  2.64,  2.63,
#         2.34,  2.55,  2.81,  2.38,  2.27,  2.17,  2.29,  2.31,  2.51,
#         2.83,  2.8 ,  2.91,  2.83,  2.8 ,  2.92,  3.07,  3.17,  3.35,
#         3.78,  4.77,  4.76,  4.62,  4.92,  5.08,  4.85,  4.87,  5.34,
#         5.72,  5.58,  5.5 ,  5.34,  5.63,  5.3 ,  5.44,  5.6 ,  5.68,
#         5.55,  6.23,  6.76,  6.84,  7.41,  7.53,  8.35,  8.13,  8.41,
#         9.76,  9.83,  7.97,  8.03,  9.52,  9.7 ,  9.53,  8.99,  9.11,
#        11.19, 11.47, 11.86, 12.81, 12.68, 12.78, 13.02, 13.49, 13.46,
#        13.74, 13.91, 13.67, 13.71, 13.65, 13.42, 13.49, 13.76, 13.47,
#        13.43, 13.65, 13.7 , 13.65, 13.45, 14.14, 14.4 , 13.89, 14.41,
#        14.39, 14.26, 14.21, 14.49, 14.65, 14.88, 15.01, 15.4 , 16.05,
#        16.13, 16.15, 16.53, 16.66, 16.8 , 17.03, 17.45, 18.27, 18.54,
#        18.62, 19.08, 19.5 , 19.71, 20.77, 21.19, 21.4 , 21.93, 22.89,
#        23.59, 23.57, 23.7 , 24.45, 25.  , 25.62, 25.61, 26.26, 27.13,
#        28.43, 28.16, 28.52, 28.18, 28.36, 29.63, 29.23, 29.49, 32.47,
#        33.24, 33.13, 32.99, 33.34, 33.88, 34.67, 34.72, 34.66, 35.81,
#        36.55, 35.97, 36.44, 37.16, 38.19, 37.91, 38.38, 38.71, 39.37,
#        39.69, 40.91, 40.85, 41.13, 41.27, 41.07, 41.29, 41.56, 41.53,
#        41.69, 41.77, 41.86, 42.32, 42.76, 43.27, 43.28, 43.08, 43.04,
#        42.94, 42.8 , 43.1 , 42.8 , 42.53, 42.7 , 42.88, 43.32, 42.96,
#        43.16, 43.4 , 43.04, 43.03, 43.77, 44.06, 43.87, 44.11, 43.68,
#        41.98, 42.18, 42.2 , 42.19, 42.01, 41.84, 42.79, 42.27, 42.38,
#        42.39, 42.07, 41.53, 41.48, 41.38, 41.41, 41.83, 41.96, 41.82,
#        41.63, 41.5 , 41.47, 41.49, 41.65, 41.55, 41.96, 42.23, 42.44,
#        42.97, 43.18, 43.21, 43.36, 43.19, 43.17, 43.33, 43.6 , 43.26,
#        43.67, 43.53, 43.9 , 44.56, 44.61, 44.6 , 44.05, 44.25, 44.79,
#        45.49, 45.28, 46.1 , 46.56, 46.17, 46.68, 45.86, 46.07, 46.17,
#        46.13, 47.01, 48.65, 47.18, 46.81, 46.85, 46.85, 46.28, 47.24,
#        47.4 , 46.38, 47.7 , 50.08, 49.97, 47.77, 47.64, 50.35, 49.31,
#        49.06, 51.59, 53.82, 54.18, 53.24, 52.44, 54.1 , 54.74, 54.59,
#        55.16, 54.38, 55.58, 55.4 , 55.38, 55.92, 56.5 , 56.89, 56.15,
#        57.11, 60.27, 61.45, 57.84, 59.92, 65.22, 67.78, 67.07, 62.79,
#        64.1 , 63.43, 63.27, 63.06, 61.96, 61.69, 60.54]), array([67.77, 69.79, 69.35, 70.66, 66.77, 62.15, 66.48, 70.05, 71.17,
#        73.84, 63.46, 63.38, 62.29, 60.17, 61.4 , 58.06, 55.12, 52.07,
#        53.84, 56.24, 55.93, 53.45, 54.18, 51.2 , 46.38, 49.82, 48.92,
#        47.77, 48.08, 48.43, 50.57, 45.21, 45.91, 45.25, 45.19, 49.23,
#        41.13, 39.63, 38.18, 39.94, 40.25, 40.07, 39.82, 39.9 , 39.29,
#        39.22, 38.75, 40.47, 38.81, 39.45, 42.13, 44.58, 43.91, 43.73,
#        42.52, 42.06, 42.53, 43.39, 43.43, 42.84, 42.62, 43.15, 43.27,
#        43.49, 43.13, 42.78, 42.79, 43.13, 42.56, 42.53, 43.01, 43.77,
#        44.19, 44.21, 43.84, 42.59, 42.54, 42.56, 42.  , 41.13, 40.75,
#        42.44, 44.88, 45.39, 42.6 , 41.21, 42.86, 44.13, 43.46, 43.19,
#        43.46, 42.57, 43.48, 43.27, 43.27, 41.88, 41.93, 42.55, 40.49,
#        40.52, 41.66, 41.49, 41.47, 40.49, 41.05, 41.31, 40.  , 39.22,
#        38.21, 37.98, 37.82, 36.46, 35.54, 35.08, 35.02, 35.09, 35.13,
#        34.91, 34.08, 34.26, 33.82, 32.95, 32.23, 30.47, 31.59, 32.05,
#        31.5 , 31.64, 33.54, 33.66, 32.65, 33.33, 33.13, 32.31, 32.28,
#        32.1 , 30.96, 30.52, 31.5 , 30.81, 29.91, 28.72, 27.75, 26.53,
#        27.24, 27.37, 26.92, 27.2 , 26.46, 25.97, 25.66, 24.87, 24.43,
#        22.88, 22.6 , 22.55, 22.04, 21.13, 20.8 , 20.49, 19.93, 19.11,
#        18.52, 17.93, 17.34, 17.36, 17.24, 16.89, 16.76, 16.84, 17.06,
#        17.07, 16.6 , 16.41, 15.87, 14.49, 14.66, 14.7 , 15.07, 14.41,
#        14.26, 14.51, 14.96, 15.  , 14.96, 14.82, 14.59, 14.23, 13.25,
#        12.86, 11.97, 11.65, 11.33, 10.82, 10.49, 10.4 , 10.01,  9.79,
#        10.02,  9.75,  9.19,  9.02,  8.63,  8.27,  7.92,  7.58,  7.48,
#         7.5 ,  6.91,  6.31,  5.92,  5.92,  6.06,  5.7 ,  5.11,  4.92,
#         5.2 ,  4.6 ,  4.22,  3.91,  4.29,  4.39,  4.01,  3.47,  3.01,
#         2.69,  2.41,  2.32,  2.54,  3.06,  2.83,  2.36,  2.26,  2.52,
#         2.09,  2.26,  2.36,  2.68,  1.92,  2.11,  2.28,  2.17,  1.66,
#         2.13,  1.23,  0.38,  1.  ,  1.34,  2.22,  2.33,  3.59,  2.29,
#         2.28,  1.74,  1.52,  2.25,  2.72,  2.72,  2.68,  3.09,  2.92,
#         2.53,  2.57,  2.98,  2.88,  3.31,  3.41,  3.76,  3.77,  3.91,
#         3.87,  3.67,  3.43,  3.55,  3.8 ,  3.9 ,  3.63,  4.15,  4.47,
#         4.71,  4.76,  4.96,  4.92,  5.25,  5.47,  5.75,  6.3 ,  6.73,
#         7.19,  7.1 ,  7.35,  7.57,  7.53,  7.63,  7.9 ,  7.86,  7.97,
#         8.12,  8.42,  8.36,  9.39,  9.75,  9.86, 10.16, 10.52, 10.74,
#        10.83, 10.92, 10.94, 10.76, 10.86, 10.98, 11.37, 12.04, 12.38,
#        12.98, 14.11, 14.24, 14.15, 15.23, 16.45, 16.28, 16.58, 16.64,
#        17.55, 18.34, 18.82, 18.95, 19.84, 21.21, 21.39, 21.61, 21.98,
#        21.65, 21.77, 21.97, 21.96, 22.28, 22.41, 22.4 , 22.92, 22.98,
#        23.56, 23.87, 23.31, 23.07, 22.68, 24.4 , 23.94, 24.16, 25.35,
#        24.93, 24.37, 25.21, 25.29, 25.62, 25.64, 26.47, 26.96, 27.97,
#        28.29, 28.11, 27.77, 27.65, 28.34, 28.78, 28.79, 29.69, 30.4 ,
#        30.  , 30.27, 30.72, 31.23, 31.24, 31.25, 32.11, 32.37, 32.99,
#        33.24, 33.84, 34.88, 35.61, 36.56, 37.19, 37.39, 38.99, 38.88,
#        40.08, 40.92, 40.61, 40.52, 40.36, 40.76, 41.06, 41.76, 41.79,
#        41.54, 41.63, 41.75, 41.26, 40.93, 40.84, 40.36, 40.54, 40.98,
#        41.37, 41.02, 41.11, 41.52, 41.77, 41.68, 41.66, 42.22, 42.92,
#        43.25, 43.37, 43.37, 43.71, 43.92, 43.83, 43.93, 44.29, 44.49,
#        44.5 , 44.88, 44.8 , 44.81, 45.08, 45.19, 45.58, 45.86, 46.43,
#        47.03, 46.7 , 46.57, 46.88, 47.14, 47.13, 47.09, 47.38, 47.19,
#        47.39, 47.21, 47.12, 47.39, 47.15, 47.46, 47.27, 47.29, 47.48,
#        47.33, 47.67, 47.5 , 47.24, 47.21, 47.15, 46.76, 46.76, 46.61,
#        46.42, 47.13, 48.09, 48.69, 49.54, 49.95, 49.43, 51.12, 52.9 ,
#        52.96, 51.88, 52.08, 55.12, 54.49, 53.95, 55.64, 55.59, 55.48,
#        55.52, 54.88, 55.89, 55.65, 56.88, 56.28, 57.14, 55.32, 58.36,
#        60.4 , 60.14, 60.02, 59.91, 60.21, 59.94, 61.59, 61.54, 61.57,
#        60.24, 61.09, 62.95, 58.71, 58.51, 59.76, 60.55, 62.12, 61.46,
#        62.34, 61.86, 61.35, 61.41, 61.98, 62.62, 62.55, 61.9 , 63.38,
#        63.78, 62.38, 62.72, 64.16, 64.06, 65.  , 65.71, 64.28, 64.69,
#        64.38, 64.07, 63.57, 64.66]), array([65.24, 66.02, 66.38, 66.59, 66.39, 67.06, 68.13, 68.74, 69.24,
#        69.19, 68.28, 68.65, 68.31, 68.55, 68.45, 67.77, 66.88, 65.56,
#        64.91, 63.74, 60.13, 59.03, 60.8 , 60.75, 61.97, 63.81, 63.55,
#        60.86, 59.99, 58.05, 58.9 , 59.6 , 58.16, 58.15, 56.63, 53.71,
#        54.56, 54.22, 55.42, 55.83, 55.61, 55.  , 55.05, 54.6 , 54.76,
#        55.03, 55.31, 55.39, 55.94, 56.07, 56.22, 54.9 , 54.98, 55.1 ,
#        55.03, 54.24, 53.7 , 53.16, 52.39, 52.27, 52.24, 51.36, 50.76,
#        50.35, 50.48, 49.57, 49.39, 49.01, 48.02, 46.91, 46.5 , 46.11,
#        46.25, 45.55, 45.14, 46.97, 47.19, 45.84, 44.63, 44.82, 45.01,
#        45.19, 45.1 , 44.54, 43.6 , 42.54, 42.1 , 41.72, 41.43, 41.26,
#        40.71, 40.1 , 39.04, 38.83, 39.  , 38.82, 39.12, 38.93, 38.04,
#        38.3 , 37.86, 36.89, 37.03, 35.79, 35.5 , 34.96, 34.85, 34.53,
#        34.39, 34.11, 34.42, 34.02, 33.45, 33.27, 33.16, 33.02, 33.44,
#        33.27, 33.05, 33.49, 33.48, 33.37, 33.32, 33.33, 33.26, 32.9 ,
#        32.43, 31.95, 31.69, 31.56, 31.12, 30.51, 30.03, 29.69, 29.95,
#        29.76, 29.47, 28.9 , 28.98, 28.87, 28.62, 28.4 , 28.3 , 28.05,
#        28.  , 28.5 , 27.65, 27.01, 26.51, 26.89, 25.74, 24.7 , 25.15,
#        25.15, 24.86, 24.73, 24.96, 25.29, 24.94, 24.88, 24.93, 24.23,
#        23.98, 23.93, 23.81, 23.53, 23.46, 22.84, 22.83, 22.4 , 22.29,
#        21.75, 21.69, 21.36, 21.16, 20.82, 20.28, 19.67, 19.49, 19.18,
#        18.94, 18.81, 18.7 , 18.18, 18.15, 18.  , 17.99, 17.73, 17.29,
#        16.44, 16.  , 15.27, 14.64, 14.61, 14.46, 14.25, 13.56, 12.99,
#        12.85, 12.37, 11.92, 11.53, 10.89, 10.41, 10.1 ,  9.52,  9.16,
#         8.36,  8.03,  7.49,  6.25,  5.62,  5.59,  6.17,  5.95,  5.75,
#         5.57,  5.54,  5.15,  5.37,  4.6 ,  4.01,  3.91,  3.84,  2.94,
#         2.84,  2.52,  2.26,  1.9 ,  2.14,  2.39,  2.31,  2.53,  2.71,
#         1.88,  1.32,  1.27,  1.14,  1.95,  0.93,  0.61,  0.34,  0.33,
#         0.17,  0.17,  0.75,  1.15,  1.19,  1.09,  0.63,  2.15,  2.85,
#         0.98,  0.93,  2.23,  1.99,  1.73,  0.76,  1.07,  2.71,  2.16,
#         2.34,  2.73,  3.1 ,  3.02,  2.55,  2.15,  1.58,  1.76,  5.  ,
#         3.9 ,  3.37,  2.72,  3.82,  3.26,  3.47,  4.01,  3.9 ,  3.68,
#         4.64,  5.23,  5.24,  5.25,  4.67,  4.71,  4.45,  4.85,  5.62,
#         5.88,  6.04,  6.58,  6.46,  6.41,  6.41,  6.63,  6.72,  7.02,
#         7.14,  6.89,  6.83,  7.28,  7.71,  7.43,  7.7 ,  8.14,  8.41,
#         8.88,  8.93,  8.84,  8.9 ,  9.1 ,  9.26,  9.56,  9.86,  9.85,
#         9.52,  9.71,  9.8 ,  9.98,  9.91, 10.01,  9.82,  9.99, 10.5 ,
#        10.3 , 10.85, 11.43, 11.55, 11.78, 11.82, 12.05, 11.88, 12.29,
#        12.63, 13.45, 13.9 , 14.42, 14.05, 14.84, 15.34, 15.53, 14.85,
#        14.58, 15.17, 15.03, 15.15, 15.78, 16.77, 17.55, 17.53, 17.77,
#        17.9 , 17.85, 17.81, 18.23, 19.53, 19.68, 19.31, 19.63, 19.26,
#        19.71, 20.54, 21.13, 20.29, 20.34, 20.25, 20.5 , 20.49, 21.01,
#        21.11, 21.46, 22.39, 22.38, 21.7 , 22.28, 22.84, 22.86, 22.2 ,
#        22.75, 22.34, 22.93, 23.49, 23.51, 24.68, 26.15, 26.35, 27.79,
#        28.21, 28.86, 28.18, 27.27, 27.59, 27.72, 28.47, 29.49, 28.63,
#        28.63, 28.9 , 29.63, 28.24, 27.48, 28.84, 30.29, 28.77, 27.65,
#        28.5 , 29.42, 29.47, 30.01, 29.94, 30.54, 31.07, 31.06, 31.68,
#        32.56, 33.7 , 35.19, 35.54, 35.76, 35.59, 36.19, 36.15, 36.74,
#        36.34, 37.16, 37.75, 38.1 , 38.13, 38.21, 38.3 , 38.27, 38.36,
#        38.66, 39.35, 39.02, 38.83, 39.17, 39.38, 39.33, 39.24, 39.93,
#        40.34, 39.92, 39.54, 39.3 , 40.12, 40.51, 40.17, 40.02, 40.25,
#        40.51, 40.44, 40.25, 40.64, 41.29, 41.28, 41.43, 41.72, 42.13,
#        41.89, 42.1 , 42.38, 42.26, 41.8 , 42.32, 41.25, 41.48, 40.57,
#        40.77, 41.5 , 42.13, 40.81, 40.02, 40.77, 41.68, 41.09, 40.56,
#        39.77, 39.28, 38.64, 40.21, 40.96, 42.13, 43.22, 45.26, 42.58,
#        50.79, 50.53, 51.  , 51.59, 58.61, 57.48, 60.21, 64.93, 63.07,
#        64.8 , 63.82, 62.39, 52.92, 54.92, 57.71, 60.16, 59.92, 56.59,
#        55.37]), array([57.99, 62.4 , 60.96, 62.83, 58.65, 56.01, 58.87, 65.26, 66.48,
#        64.57, 64.85, 65.22, 59.44, 60.91, 59.46, 57.86, 57.01, 60.85,
#        58.22, 51.76, 54.32, 58.36, 60.2 , 60.82, 59.63, 54.32, 51.97,
#        53.94, 54.99, 53.67, 52.23, 54.03, 55.36, 53.81, 53.58, 54.1 ,
#        51.49, 51.32, 49.86, 48.07, 49.41, 48.79, 50.2 , 50.61, 51.26,
#        49.97, 48.88, 47.45, 48.41, 48.31, 48.  , 46.61, 46.48, 46.4 ,
#        45.35, 46.02, 46.67, 48.03, 47.44, 46.89, 43.97, 45.48, 45.58,
#        44.62, 43.66, 43.76, 44.07, 43.51, 43.23, 41.92, 41.61, 41.67,
#        41.22, 40.33, 40.17, 40.04, 39.25, 38.17, 34.81, 36.14, 36.11,
#        35.59, 35.55, 35.67, 35.55, 35.23, 34.38, 33.3 , 32.73, 32.93,
#        33.05, 32.42, 32.14, 31.92, 31.68, 31.99, 32.3 , 32.3 , 32.12,
#        31.21, 30.72, 29.65, 29.21, 28.48, 27.42, 27.12, 27.12, 26.97,
#        26.77, 26.5 , 26.35, 26.  , 26.19, 26.08, 25.98, 25.54, 25.36,
#        25.69, 25.01, 24.17, 24.31, 24.17, 23.8 , 24.09, 24.17, 23.81,
#        23.66, 23.14, 21.73, 22.53, 22.63, 22.46, 22.02, 21.59, 21.5 ,
#        21.38, 20.19, 19.47, 19.32, 19.33, 19.91, 19.88, 19.36, 19.29,
#        19.25, 18.8 , 18.16, 17.86, 17.09, 17.06, 16.91, 16.9 , 16.78,
#        16.86, 16.78, 16.84, 16.25, 16.61, 16.27, 15.79, 16.  , 15.88,
#        15.34, 15.3 , 15.34, 14.9 , 14.64, 14.5 , 14.16, 14.04, 13.97,
#        14.1 , 14.3 , 13.64, 13.52, 13.27, 13.12, 12.8 , 12.44, 12.64,
#        12.92, 13.08, 13.01, 12.41, 12.26, 12.37, 12.58, 12.68, 12.44,
#        12.8 , 12.54, 12.37, 12.4 , 12.39, 12.09, 12.11, 12.68, 13.15,
#        13.23, 13.38, 13.84, 14.02, 14.16, 14.44, 14.23, 14.35, 14.61,
#        14.75, 15.06, 15.19, 15.36, 15.51, 15.57, 15.82, 15.84, 15.84,
#        15.65, 15.65, 15.75, 15.7 , 15.62, 15.69, 15.84, 15.79, 16.03,
#        16.27, 16.79, 16.95, 17.1 , 16.87, 16.83, 16.34, 16.33, 16.51,
#        16.41, 16.23, 15.95, 15.83, 15.68, 15.54, 15.27, 14.89, 14.8 ,
#        14.58, 14.47, 14.31, 14.09, 13.6 , 13.63, 13.87, 13.84, 13.58,
#        13.03, 13.09, 12.97, 12.73, 12.68, 12.47, 12.37, 11.93, 11.76,
#        11.57, 11.54, 11.28, 11.09, 11.27, 10.99, 10.65, 10.32,  9.94,
#         9.77,  9.59,  9.36,  9.28,  9.  ,  9.18,  9.09,  8.78,  8.69,
#         9.37,  9.17,  8.48,  8.46,  7.99,  7.68,  7.24,  6.92,  6.62,
#         6.29,  5.8 ,  5.26,  5.2 ,  5.11,  4.78,  4.43,  4.15,  3.45,
#         3.  ,  2.99,  2.75,  2.67,  2.87,  3.35,  3.72,  3.86,  3.83,
#         3.67,  3.86,  3.98,  4.07,  4.27,  4.67,  5.17,  5.15,  5.16,
#         5.72,  5.88,  6.64,  6.58,  6.35,  7.32,  8.1 ,  8.02,  8.03,
#         8.31,  8.01,  8.79,  9.8 ,  9.21,  9.9 , 10.73, 10.74, 10.32,
#        10.17, 11.13, 11.31, 10.72, 10.93, 10.19,  9.91,  9.63, 11.58,
#        12.52, 12.52, 11.26, 13.17, 11.83, 11.14, 11.05, 10.74, 11.77,
#        14.24, 13.16, 12.04, 13.98, 13.35, 14.05, 14.33, 14.23, 15.89,
#        15.33, 15.54, 15.63, 16.25, 17.12, 17.37, 17.75, 18.2 , 18.27,
#        18.09, 18.07, 17.98, 18.46, 18.67, 19.19, 19.96, 20.38, 20.98,
#        21.41, 21.53, 21.42, 21.26, 21.58, 21.86, 21.98, 21.69, 21.67,
#        21.89, 22.04, 22.37, 22.49, 22.4 , 22.18, 22.02, 22.11, 22.22,
#        22.27, 22.15, 21.7 , 21.44, 21.17, 20.89, 20.53, 20.43, 20.04,
#        20.15, 20.28, 20.01, 19.74, 19.7 , 19.78, 19.74, 19.4 , 19.41,
#        19.57, 19.4 , 19.29, 19.05, 18.87, 18.87, 18.47, 18.24, 18.34,
#        18.  , 17.48, 17.16, 16.42, 16.35, 15.91, 15.66, 15.44, 15.23,
#        14.89, 14.69, 14.4 , 14.39, 13.94, 13.77, 13.4 , 12.95, 12.54,
#        12.08, 11.97, 12.11, 11.9 , 11.86, 11.81, 11.83, 11.72, 11.52,
#        10.85, 10.7 , 10.93, 11.41, 10.66, 10.24, 10.12,  9.73,  9.29,
#         9.07,  9.03,  8.85,  8.44,  8.01,  7.51,  7.06,  6.68,  6.98,
#         7.06,  6.76,  7.04,  7.54,  7.52,  7.52,  7.75,  8.22,  8.44,
#         8.3 ,  8.24,  8.61, 10.14,  9.46, 10.62, 10.81, 10.18, 10.18,
#         9.95, 11.11, 12.51, 13.27, 13.52, 13.52, 12.68, 12.09, 12.82,
#        12.84, 12.88, 12.86, 13.05, 12.58, 11.78, 13.52, 13.24, 12.16,
#        11.98, 13.24, 11.95, 11.43, 11.68, 13.53, 13.58, 12.41, 13.06,
#        13.67, 14.83, 15.82, 16.04, 16.59, 16.68, 17.26, 16.3 , 16.85,
#        17.43, 17.77, 18.05, 18.62, 19.3 , 20.34, 20.3 , 20.96, 21.51,
#        21.27, 21.51, 22.22, 22.56, 22.94, 23.1 , 23.36, 23.85, 24.05,
#        24.44, 24.54, 24.79, 25.09, 25.52, 25.99, 26.17, 26.4 , 26.29,
#        26.44, 27.02, 27.5 , 27.59, 28.03, 28.38, 28.65, 29.13, 29.3 ,
#        29.51, 29.61, 29.43, 29.57, 29.47, 29.64, 29.82, 29.86, 30.11,
#        30.36, 30.55, 30.66, 30.98, 31.39, 31.75, 32.04, 32.26, 32.3 ,
#        32.41, 32.63, 32.95, 33.37, 33.69, 34.13, 34.04, 33.87, 33.94,
#        33.86, 34.08, 34.51, 34.8 , 34.95, 35.13, 35.28, 35.35, 35.34,
#        35.76, 36.33, 36.4 , 36.8 , 37.23, 37.24, 37.15, 37.17, 37.09,
#        37.17, 37.45, 37.84, 38.45, 38.76, 38.78, 38.89, 39.04, 39.19,
#        39.11, 38.56, 38.41, 38.71, 39.05, 39.35, 39.35, 39.52, 39.44,
#        39.51, 39.89, 40.24, 40.29, 40.15, 40.72, 41.43, 41.54, 41.62,
#        41.77, 41.92, 41.98, 42.14, 42.46, 42.7 , 43.48, 44.04, 43.72,
#        43.8 , 43.55, 43.47, 43.62, 43.89, 43.78, 44.35, 44.65, 44.58,
#        44.62, 44.31, 44.07, 43.84, 43.78, 44.04, 43.92, 44.63, 44.99,
#        45.64, 45.75, 45.56, 45.44, 45.45, 45.75, 45.77, 45.87, 46.2 ,
#        46.79, 47.  , 46.78, 46.97, 47.  , 47.05, 47.21, 46.87, 46.74,
#        46.84, 46.66, 45.97, 45.98, 47.66, 48.14, 48.67, 49.76, 50.81,
#        51.31, 51.81, 52.73, 53.37, 53.29, 53.68, 54.23, 54.63, 54.74,
#        55.27, 55.58, 55.79, 55.94, 56.02, 56.53, 56.72, 57.05, 57.43,
#        57.21, 57.14, 58.52, 58.46, 57.18, 59.8 , 60.93, 60.01, 59.84,
#        59.9 , 60.43, 61.03, 62.22, 61.19, 61.  , 61.09, 64.33, 64.55,
#        67.61, 66.18, 66.  , 68.97, 69.8 , 70.08, 71.7 , 72.47, 73.12,
#        72.51, 70.65, 68.59, 68.3 , 70.25, 69.27, 68.45, 68.24, 68.62])]]

# %%
######################
## Make a nice rmw plot for each eye pass!
######################

# make figure before loop and add to it!
plt.figure( figsize=(14, 11))
lw = 2.5
helper_fns.change_font_sizes(16, 16)

# create a colormap for nice plotting!
start = 0.0
stop = 1.0


number_of_lines= pass_counter # the number of lines, inputed manually :(

cm_subsection = np.linspace(start, stop, number_of_lines) 
colors = [ cm.jet(x) for x in cm_subsection ]

# simple sums used to plot proper line colors below
simple_sum1 = 0 
simple_sum2 = 0 

# do this for every flight date in this case (defined in code block above)
print( "Number of TC flight days = " + str( len( dataset_numbers)))

for i in range( len( dataset_numbers)):
    
    # make plots of total wind speed and vertical vels along new rmw axes!
    plt.subplot(211)

    plt.title( "All Vertical and Total Wind Speeds from TC Ida and Sam")

    plt.ylabel("Total Wind Speed (m/s)")
    plt.xlim( [-1.2, 1.2])

    # plot each of the vel profiles
    for j in range( len( rmw_total[ i])):
        label = "TC " + names[i] + ", " + dates[ i] + ", pass " + str( j)
        
        plt.plot( rmw_total[i][j], spd_total[i][j], c=colors[ simple_sum1], label=label, linewidth=lw, alpha=.7)
        simple_sum1 += 1
        
    if i == len( dataset_numbers) - 1:
        plt.legend( bbox_to_anchor=(1.03, 1.05), fancybox=False, shadow=False, fontsize=14, facecolor='w', framealpha=1)
        plt.grid()
        
    plt.subplot(212)
    plt.ylabel("Vertical Velocity (m/s)")
    plt.xlabel("Radius of Maximum Wind")
    plt.xlim( [-1.2, 1.2])

    # plot each of the vel profiles
    for j in range( len( rmw_total[ i])):
        label = "TC " + names[i] + ", " + dates[ i] + ", pass " + str( j)
        plt.plot( rmw_total[i][j], w_total[i][j], c=colors[ simple_sum2], label=label, linewidth=lw, alpha=.7)
        simple_sum2 += 1


    if i == len( dataset_numbers) - 1:
        plt.legend( bbox_to_anchor=(1.03, 1.05), fancybox=False, shadow=False, fontsize=14, facecolor='w', framealpha=1)
        plt.grid()
# Out:
# Number of TC flight days = 5

# %%
'''

# simple case trying to figure out what's going wrong with the code above :/ 
# I think it has to be something to do with the final loop...
# move under "setup steps" to get this test code to work
# I solved the error! I was missing a - sign lol

date_i = 0
pass_i = 0
rmw_i = 5

# print out the rmw, wind speed, and vert vel values at this set of indices!
rmw_val = rmw_total[date_i][ pass_i][rmw_i]
print( rmw_val)

# sort through the bins
# -1 to account for two bins being chosen in the beginning
for bin_i in range( len( bins) - 1):

    # check if the current rmw value is within this bin!
    bin_val_i = bins[ bin_i]
    bin_val_next = bins[ bin_i + 1]
    
    # account for negative cases too :)
    if ( rmw_val >= bin_val_i and rmw_val < bin_val_next) or (- rmw_val >= bin_val_i and - rmw_val < bin_val_next):

        print( "True!")
        print( bin_val_i)

        # append the values to the correct summation matrix
        # also append the rmw values for testing!

        # need to correct this: append to a specific list (based on the bin) in the outer list!
        rmwsorted[ bin_i].append( rmw_val)
        spdsorted[ bin_i].append( spd_total[ date_i][ pass_i][ rmw_i])
        wsorted[ bin_i].append( w_total[ date_i][ pass_i][ rmw_i])   

    else:
        pass
        print( "False :(")
        # print( rmw_val)

print( rmwsorted)
print( spdsorted)
print( wsorted)

'''
# Out:
# '\n\n# simple case trying to figure out what\'s going wrong with the code above :/ \n# I think it has to be something to do with the final loop...\n# move under "setup steps" to get this test code to work\n# I solved the error! I was missing a - sign lol\n\ndate_i = 0\npass_i = 0\nrmw_i = 5\n\n# print out the rmw, wind speed, and vert vel values at this set of indices!\nrmw_val = rmw_total[date_i][ pass_i][rmw_i]\nprint( rmw_val)\n\n# sort through the bins\n# -1 to account for two bins being chosen in the beginning\nfor bin_i in range( len( bins) - 1):\n\n    # check if the current rmw value is within this bin!\n    bin_val_i = bins[ bin_i]\n    bin_val_next = bins[ bin_i + 1]\n    \n    # account for negative cases too :)\n    if ( rmw_val >= bin_val_i and rmw_val < bin_val_next) or (- rmw_val >= bin_val_i and - rmw_val < bin_val_next):\n\n        print( "True!")\n        print( bin_val_i)\n\n        # append the values to the correct summation matrix\n        # also append the rmw values for testing!\n\n        # need to correct this: append to a specific list (based on the bin) in the outer list!\n        rmwsorted[ bin_i].append( rmw_val)\n        spdsorted[ bin_i].append( spd_total[ date_i][ pass_i][ rmw_i])\n        wsorted[ bin_i].append( w_total[ date_i][ pass_i][ rmw_i])   \n\n    else:\n        pass\n        print( "False :(")\n        # print( rmw_val)\n\nprint( rmwsorted)\nprint( spdsorted)\nprint( wsorted)\n\n'

# %%
# pick a bin width for rmw values, sort velocities into those bins, and 
# calculate important quantities like the mean, standard deviation, and confidence levels! 

### important! instead of going from -1 < RMW < 1, sort from 0 to 1! the negative distinction doesn't matter here
# setup steps

# .005 is an interesting bin width! anything larger than .01 lacks resolution, smaller than .005 is too noisy
binwidth = .01 # bin width from 0 to 1

# make an array representing the bins! 
bins = np.arange(0, 1.00001, step=binwidth)

# create an array of midpoints (right between two given binwidths)
# will be 1 val shorter than bins array
# used for plotting later
midpoints = []
for i in range( len( bins) - 1):
    midpoints.append( (bins[ i] + bins[ i+1]) / 2)

# print( bins)
# print( midpoints)

# initialize a list of lists, number of inner lists should be = number of bins
rmwsorted = []
spdsorted = []
wsorted = []
for i in range( len( bins) - 1):
    rmwsorted.append( [])
    spdsorted.append( [])
    wsorted.append( [])

# print( len( spdsorted))
# print( len( midpoints))

# simple sum to print the current pass number for the user
case_count = 0

# %%
# loop steps: actually do the averaging, etc!
# do this for every date that the P-3 flew in Sam
for date_i in range( len( w_total)):

    # do this for every eye pass for a given date:
    for pass_i in range( len( w_total[ date_i])):

        print( "Case " + str( case_count) + " completed")
        case_count += 1
  
        # sort through every rmw axis value for a given eye pass: check if it's within the bin!
        for rmw_i in range( len( rmw_total[ date_i][ pass_i] )):
            # locally define the current value for convenience :)
            rmw_val = rmw_total[date_i][ pass_i][rmw_i]
                        
            # print( rmw_val)
            
            # sort through the bins
            # -1 to account for two bins being chosen in the beginning
            for bin_i in range( len( bins) - 1):
              
                # check if the current rmw value is within this bin!
                bin_val_i = bins[ bin_i]
                bin_val_next = bins[ bin_i + 1]
                
                # print( bin_val_i)
                # print( bin_val_next)
                # print( '\n')
                
                # account for negative cases too :)
                
                ##############
                # important!
                # maybe round to the 2nd or 3rd decimal place for this step?
                
                if ( rmw_val >= bin_val_i and rmw_val < bin_val_next) or (- rmw_val >= bin_val_i and - rmw_val < bin_val_next):
                  
                    # print( "True!")
                    
                    # append the values to the correct summation matrix
                    # also append the rmw values for testing!
                    
                    # need to correct this: append to a specific list (based on the bin) in the outer list!
                    rmwsorted[ bin_i].append( rmw_val)
                    spdsorted[ bin_i].append( spd_total[ date_i][ pass_i][ rmw_i])
                    wsorted[ bin_i].append( w_total[ date_i][ pass_i][ rmw_i])   
                
                    # else:
                    # print( "False :(")
                    # print( rmw_val)

'''
# print out the results!!!!
print( len( rmwsorted))
print( len( spdsorted))
print( len( wsorted))

case = 99
print( len( rmwsorted[case]))
print( len( wsorted[case]))
print( len( spdsorted[case]))
'''
# Out:
# Case 0 completed
# Case 1 completed
# Case 2 completed
# Case 3 completed
# Case 4 completed
# Case 5 completed
# Case 6 completed
# Case 7 completed
# Case 8 completed
# Case 9 completed
# Case 10 completed
# Case 11 completed
# Case 12 completed
# Case 13 completed
# Case 14 completed
# '\n# print out the results!!!!\nprint( len( rmwsorted))\nprint( len( spdsorted))\nprint( len( wsorted))\n\ncase = 99\nprint( len( rmwsorted[case]))\nprint( len( wsorted[case]))\nprint( len( spdsorted[case]))\n'

# %%
# testing 
# print out the final arrays!


# print out the results!!!!
# print( len( rmwsorted))
# print( len( spdsorted))
# print( len( wsorted))
# print( spdsorted)

# %%
# testing
# print a distribution of averaged values! as a line plot, both raw and averaged values...
# how did putting values into bins go???

plt.figure( figsize=(10, 10))
helper_fns.change_font_sizes( 14, 14)
plt.xlabel( "RMW Bin Width (0 to 1)")
plt.ylabel( "Number of Cases per Bin")

bincount = []
# count the number of cases for each rmw bin; save in a separate list for plotting
for i in range( len( rmwsorted)):
    bincount.append( len( rmwsorted[ i]))
    
plt.scatter( midpoints, bincount, c='g', s=25)

# %%
# make plots like the ones above, but with the mean values and confidence intervals instead of individual passes!

# average each of the speeds saved in the separate arrays (all the speeds belonging to that bin)
spdavg = []
spdlowc = []
spdhighc = []

wavg = []
wlowc = []
whighc = []

confidence=.95
for i in range( len( midpoints)):
    mean, lowc, highc = extra_stats.mean_confidence_interval( 
                np.ma.masked_array( spdsorted[ i], np.isnan( spdsorted[ i])), confidence=confidence)
    spdavg.append(  mean)
    spdlowc.append(  lowc)
    spdhighc.append(  highc)

    mean, lowc, highc = extra_stats.mean_confidence_interval( 
                np.ma.masked_array( wsorted[ i], np.isnan( wsorted[ i])), confidence=.95)
    wavg.append(  mean)
    wlowc.append(  lowc)
    whighc.append(  highc)

# %%
# make figure 
plt.figure( figsize=(8.5, 11))
lw = 2.5
helper_fns.change_font_sizes(16, 16)

# make plots of total wind speed and vertical vels along new rmw axes!
plt.subplot(211)
plt.title( "Averaged Vertical and Total Wind Speeds from TC Ida and Sam")

plt.ylabel("Averaged Total Wind Speed (m/s)")
plt.xlim( [-.2, 1.2])
plt.plot( midpoints, spdavg, c='c', linewidth=lw)
plt.plot( midpoints, spdlowc, c='k', linewidth=lw/2)
plt.plot( midpoints, spdhighc, c='k', linewidth=lw/2)


plt.subplot(212)
plt.ylabel("Averaged Vertical Velocity (m/s)")
plt.xlabel("Radius of Maximum Wind")
plt.xlim( [-.2, 1.2])
plt.plot( midpoints, wavg, c='y', linewidth=lw)
plt.axhline( y=0, c='k', linewidth=lw)
plt.plot( midpoints, wlowc, c='k', linewidth=lw/2)
plt.plot( midpoints, whighc, c='k', linewidth=lw/2)

# %%
# make figure 
plt.figure( figsize=(8.5, 11))
lw = 2.
helper_fns.change_font_sizes(16, 16)

# make plots of total wind speed and vertical vels along new rmw axes!
plt.subplot(211)
plt.title( "Averaged Vertical and Total Wind Speeds from TC Sam")

plt.ylabel("Averaged Total Wind Speed (m/s)")
plt.xlim( [-.2, 1.2])
plt.plot( midpoints, spdavg, c='b', linewidth=lw, label="Mean Value")

ax = plt.gca()
ax.fill_between( midpoints, spdlowc, spdhighc, color='b', alpha=0.3, label=str( int(confidence*100)) + "% Confidence")
ax.legend()

plt.subplot(212)
plt.ylabel("Averaged Vertical Velocity (m/s)")
plt.xlabel("Radius of Maximum Wind")
plt.xlim( [-.2, 1.2])
plt.plot( midpoints, wavg, c='g', linewidth=lw, label="Mean Value")
plt.axhline( y=0, c='k', linewidth=lw, label="0 m/s cutoff" )

ax = plt.gca()
ax.fill_between( midpoints, wlowc, whighc, color='g', alpha=0.3, label=str( int(confidence*100)) + "% Confidence")
ax.legend()
