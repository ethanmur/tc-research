# %%
import os
os.chdir("/Users/etmu9498/research/data/guo-data/Python_Wavelet_Ethan/")
import ka_wavelet_le_cross_scalogram_100m_along_distance as run

run.main()
# Out:
# WVMR lag1 =  0.9719882621570283
# W (m/s) lag1 =  0.8879083296569508

# %%
# check out datasets included in Guo's test file
import os
import netCDF4
import xarray as xr

path_pm = "/Users/etmu9498/research/data/guo-data/Python_Wavelet_Ethan/"
os.chdir(path_pm)

# f = netCDF4.Dataset('20190709a.c25.nc', 'r')
f = xr.open_dataset('20190709a.c25.nc')

print(f.time[0].values)
print(f.time[-1].values)

f
# Out:
# 2019-07-09T13:42:30.000000000
# 2019-07-09T16:53:07.000000000
# <xarray.Dataset>
# Dimensions:      (time: 11438, sps25: 25, sps10: 10, Vec31: 31)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-07-09T13:42:30 ... 2019-07-09T16:...
#     AVlat        (time, sps25) float32 ...
#     AVlon        (time, sps25) float32 ...
#     AVzmsl       (time, sps25) float32 ...
# Dimensions without coordinates: sps25, sps10, Vec31
# Data variables: (12/127)
#     TIME         (time) float32 ...
#     DATE         (time) float32 ...
#     HOUR         (time) timedelta64[ns] ...
#     MINUTE       (time) timedelta64[ns] ...
#     SECOND       (time) timedelta64[ns] ...
#     ps_weston    (time, sps25) float32 ...
#     ...           ...
#     AVnvelrms    (time) float32 ...
#     AVevelrms    (time) float32 ...
#     AVdvelrms    (time) float32 ...
#     AVrollrms    (time) float32 ...
#     AVpitchrms   (time) float32 ...
#     AVtheadrms   (time) float32 ...
# Attributes: (12/84)
# ...
