# %%
import os
os.chdir( "/Users/etmu9498/research/code/scripts/statistics")
import cloud_clusters
import cloud_cluster_peaks
cloud_clusters.clusters_all_tc_eyes( tc='sam', no_eyewalls=True, cluster_threshold=.250, print_stats=True, surface_cases=False, new_algorithm=False)
# cloud_cluster_peaks.clusters_all_peaks( tc='sam', no_eyewalls=True)
# Out:
# TC Sam
# Number of crl files: 7
#
# TC Sam, 09-26, Eye Pass 1
# Using new algorithm
# heights: values and count
# 23
# [1.5949132432432798, 0.8668180000000675, 0.07724000000009701, 0.544405000000081, 0.8517400000000701, 2.175850000000023, 2.4784000000000126, 2.7026200000000045, 1.6065400000000443, 2.4142100000000153, 2.6826000000000056, 2.0611233333333616, 2.3031200000000203, 0.5722900000000829, 2.575926666666678, 0.8313700000000739, 2.0003200000000323, 1.4738800000000518, 0.8727796000000747, 1.3406650000000586, 2.398352500000021, 1.7023025000000462, 0.9229200000000746]
# widths: values and count
# 23
# [9.48860000000127, 1.0679500000021562, 0.259749999998121, 0.8083500000000186, 0.0, 0.2794000000001233, 0.0, 0.5348500000000058, 0.0, 0.0, 0.0, 0.5227500000019063, 0.0, 0.5284500000000207, 0.5088500000001659, 0.0, 0.775199999999586, 0.0, 6.201600000002145, 0.2563500000019303, 0.7764999999999418, 0.7729500000020835, 0.0]
# widths without 0 values: count
# 14
#
#
#
# ...
